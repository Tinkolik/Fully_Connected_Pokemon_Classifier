# %%
import os
import glob
import random

import torch
import torchvision
import numpy as np
import cv2
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch import nn
from torchvision import transforms
import torch.nn.functional as F

from IPython.display import Image

# %% [markdown]
# Подключаем cuda

# %%
if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

device
# Out:
# 'cuda'

# %% [markdown]
# ## Датасет

# %% [markdown]
# Ссылка на датасет - https://www.kaggle.com/datasets/lantian773030/pokemonclassification
#
# Датасет состоит из изображений покемонов, разделенных на классы.
#
# Всего 150 классов.
#
# Изображения изначально разных размеров, приведем изображения к одному размеру 100 на 100 пикселей

# %%
DATA_PATH = r'D:\ProgrammingPython\neural_networks\PokemonData'
DATA_PATH
# Out:
# 'D:\\ProgrammingPython\\neural_networks\\PokemonData'

# %%
classes = {n: cls for n,cls in enumerate(os.listdir(DATA_PATH))}
classes_invert = {value:key for key, value in classes.items() }

# %%
import os
import glob

# %%
classes_img_stat = {}
for cls in os.listdir(DATA_PATH):
    cls_path = os.path.join(DATA_PATH, cls)
    #print(os.listdir(cls_path))
    classes_img_stat[cls] = []
    for img_name in os.listdir(cls_path):
        img_path = os.path.join(cls_path, img_name)
        #print(img_path)
        img = cv2.imread(img_path)
        # cv2.imshow(img_path, img)
        # cv2.waitKey(0)
        # cv2.destroyAllWindows()
        classes_img_stat[cls].append(img.shape[:2])

classes_img_stat
# Out:
# {'Abra': [(220, 229),
#   (422, 422),
#   (723, 723),
#   (597, 597),
#   (170, 170),
#   (238, 226),
#   (279, 280),
#   (704, 711),
#   (552, 552),
#   (210, 218),
#   (250, 250),
#   (702, 702),
#   (1382, 1440),
#   (256, 264),
#   (549, 549),
#   (207, 207),
#   (267, 272),
#   (442, 445),
#   (189, 189),
#   (192, 193),
#   (500, 500),
#   (268, 268),
#   (800, 800),
#   (255, 255),
#   (227, 227),
#   (699, 699),
#   (449, 457),
#   (387, 387),
#   (2000, 2000),
#   (550, 547),
#   (320, 318),
#   (128, 128),
#   (1063, 1079),
#   (521, 521),
#   (67, 67)],
#  'Aerodactyl': [(230, 230),
#   (828, 839),
#   (941, 954),
#   (740, 747),
#   (342, 342),
#   (156, 156),
#   (720, 725),
#   (210, 210),
#   (593, 600),
#   (210, 210),
#   (1033, 1065),
#   (224, 224),
#   (229, 228),
#   (443, 443),
#   (240, 249),
#   (367, 367),
#   (206, 206),
#   (116, 116),
#   (441, 441),
#   (340, 340),
#   (300, 275),
#   (256, 256),
#   (250, 229),
#   (278, 274),
#   (190, 190),
#   (169, 169),
#   (137, 137),
#   (181, 182),
#   (473, 478),
#   (151, 151),
#   (718, 723),
#   (244, 244),
#   (372, 373),
#   (178, 178),
#   (211, 211)],
#  'Alakazam': [(162, 155),
#   (626, 624),
#   (555, 416),
#   (230, 210),
#   (124, 144),
#   (674, 684),
#   (250, 250),
#   (380, 380),
#   (1196, 1233),
#   (315, 326),
#   (256, 256),
#   (263, 300),
#   (172, 158),
#   (300, 278),
#   (881, 1174),
#   (341, 343),
#   (152, 148),
#   (618, 618),
#   (606, 566),
#   (645, 630),
#   (170, 178),
#   (525, 427),
#   (231, 224),
#   (780, 785),
#   (299, 300),
#   (1271, 1208)],
#  'Alolan Sandslash': [(879, 909),
#   (500, 500),
#   (300, 287),
#   (197, 196),
#   (166, 162),
#   (174, 174),
#   (500, 500),
#   (325, 325),
#   (272, 272),
#   (656, 649),
#   (256, 187),
#   (269, 269),
#   (297, 301),
#   (635, 641),
#   (240, 240),
#   (300, 278),
#   (313, 313),
#   (381, 381),
#   (197, 197),
#   (167, 175),
#   (160, 160),
#   (191, 191),
#   (1037, 1098),
#   (463, 466),
#   (166, 162),
#   (1020, 1020),
#   (236, 236),
#   (225, 225),
#   (194, 192),
#   (225, 224),
#   (225, 224),
#   (218, 231),
#   (204, 201),
#   (220, 212),
#   (119, 122),
#   (225, 225),
#   (225, 225),
#   (720, 1280),
#   (1149, 1280),
#   (894, 894),
#   (250, 257)],
#  'Arbok': [(602, 607),
#   (800, 800),
#   (405, 360),
#   (728, 732),
#   (574, 564),
#   (199, 199),
#   (157, 157),
#   (256, 256),
#   (208, 208),
#   (534, 534),
#   (2000, 2000),
#   (182, 182),
#   (434, 434),
#   (192, 192),
#   (135, 141),
#   (316, 316),
#   (120, 122),
#   (500, 500),
#   (270, 270),
#   (165, 165),
#   (189, 189),
#   (1077, 1085),
#   (191, 191),
#   (251, 248),
#   (763, 763),
#   (231, 231),
#   (882, 884),
#   (758, 754),
#   (511, 470),
#   (203, 203),
#   (652, 669),
#   (543, 543),
#   (800, 800),
#   (800, 800),
#   (389, 389),
#   (572, 562),
#   (664, 664),
#   (244, 241),
#   (802, 802),
#   (140, 142),
#   (326, 300)],
#  'Arcanine': [(289, 300),
#   (420, 420),
#   (465, 463),
#   (141, 142),
#   (168, 168),
#   (318, 318),
#   (573, 573),
#   (360, 362),
#   (838, 838),
#   (740, 740),
#   (775, 767),
#   (152, 152),
#   (193, 193),
#   (686, 686),
#   (569, 559),
#   (120, 120),
#   (800, 800),
#   (233, 233),
#   (670, 669),
#   (335, 336),
#   (211, 211),
#   (248, 248),
#   (256, 256),
#   (640, 636),
#   (699, 699),
#   (295, 295),
#   (250, 250),
#   (775, 768),
#   (2053, 2122),
#   (860, 865),
#   (124, 128),
#   (428, 424),
#   (2570, 2570),
#   (352, 352),
#   (710, 710),
#   (800, 800),
#   (597, 597),
#   (1248, 1251),
#   (146, 146),
#   (830, 820),
#   (807, 804)],
#  'Articuno': [(300, 266),
#   (378, 375),
#   (716, 721),
#   (256, 256),
#   (503, 475),
#   (1159, 1152),
#   (518, 525),
#   (306, 306),
#   (781, 781),
#   (191, 192),
#   (684, 695),
#   (501, 501),
#   (402, 402),
#   (709, 736),
#   (266, 268),
#   (1176, 1176),
#   (248, 247),
#   (851, 864),
#   (407, 407),
#   (969, 966),
#   (819, 818),
#   (222, 224),
#   (401, 408),
#   (1100, 1070),
#   (458, 458),
#   (450, 453),
#   (236, 236),
#   (1147, 1142),
#   (1254, 1254),
#   (262, 264),
#   (244, 240),
#   (688, 688),
#   (250, 250),
#   (389, 389),
#   (252, 252),
#   (336, 344),
#   (803, 804),
#   (306, 312),
#   (576, 576),
#   (250, 250),
#   (700, 700),
#   (300, 265),
#   (233, 234),
#   (729, 729),
#   (493, 493)],
#  'Beedrill': [(502, 466),
#   (869, 874),
#   (359, 361),
#   (283, 267),
#   (583, 597),
#   (250, 250),
#   (824, 824),
#   (152, 152),
#   (764, 797),
#   (176, 176),
#   (236, 236),
#   (281, 274),
#   (362, 352),
#   (372, 372),
#   (879, 889),
#   (763, 763),
#   (320, 320),
#   (300, 273),
#   (225, 225),
#   (372, 372),
#   (724, 724),
#   (224, 211),
#   (189, 189),
#   (380, 380),
#   (538, 485),
#   (355, 355),
#   (290, 290),
#   (283, 297),
#   (600, 600),
#   (514, 500),
#   (320, 294),
#   (189, 189),
#   (559, 559),
#   (162, 162)],
#  'Bellsprout': [(297, 297),
#   (670, 670),
#   (498, 498),
#   (213, 214),
#   (353, 350),
#   (858, 840),
#   (219, 219),
#   (177, 179),
#   (1081, 1020),
#   (934, 900),
#   (373, 373),
#   (420, 420),
#   (250, 250),
#   (228, 210),
#   (245, 243),
#   (61, 61),
#   (268, 268),
#   (731, 700),
#   (512, 510),
#   (439, 438),
#   (234, 234),
#   (463, 463),
#   (1280, 1280),
#   (683, 672),
#   (587, 592),
#   (332, 312),
#   (912, 912),
#   (147, 147),
#   (161, 161),
#   (1428, 1425),
#   (356, 348),
#   (163, 163),
#   (555, 555),
#   (800, 800),
#   (183, 183),
#   (480, 485),
#   (148, 148),
#   (146, 146),
#   (193, 193),
#   (642, 628)],
#  'Blastoise': [(303, 314),
#   (881, 902),
#   (2008, 2006),
#   (563, 563),
#   (400, 400),
#   (376, 376),
#   (119, 124),
#   (590, 590),
#   (195, 195),
#   (876, 876),
#   (509, 500),
#   (228, 222),
#   (238, 238),
#   (226, 210),
#   (741, 743),
#   (716, 716),
#   (935, 935),
#   (1088, 1042),
#   (721, 721),
#   (610, 628),
#   (231, 231),
#   (537, 543),
#   (256, 256),
#   (458, 458),
#   (2000, 2000),
#   (742, 740),
#   (727, 727),
#   (365, 364),
#   (522, 509),
#   (250, 250),
#   (1052, 1100),
#   (730, 599),
#   (488, 488),
#   (791, 816),
#   (172, 172),
#   (350, 350),
#   (1500, 1500),
#   (593, 588),
#   (810, 810),
#   (120, 120),
#   (709, 712),
#   (592, 566)],
#  'Bulbasaur': [(900, 900),
#   (893, 895),
#   (749, 800),
#   (894, 894),
#   (1132, 1057),
#   (939, 1024),
#   (1132, 1057),
#   (905, 800),
#   (669, 669),
#   (891, 1024),
#   (458, 462),
#   (4356, 5000),
#   (985, 1037),
#   (898, 900),
#   (909, 1024),
#   (1072, 900),
#   (614, 614),
#   (630, 758),
#   (805, 900),
#   (893, 895),
#   (925, 864),
#   (1024, 1024),
#   (800, 800),
#   (464, 495),
#   (819, 975),
#   (998, 1000),
#   (912, 877),
#   (720, 801),
#   (1080, 1155),
#   (554, 530),
#   (141, 153),
#   (713, 713),
#   (700, 700),
#   (281, 300),
#   (526, 698),
#   (1500, 1500),
#   (866, 923),
#   (156, 155),
#   (788, 837),
#   (464, 476),
#   (603, 616)],
#  'Butterfree': [(500, 598),
#   (293, 352),
#   (225, 300),
#   (720, 770),
#   (479, 520),
#   (736, 736),
#   (435, 497),
#   (148, 179),
#   (329, 350),
#   (728, 800),
#   (921, 867),
#   (768, 810),
#   (241, 300),
#   (1148, 1275),
#   (266, 300),
#   (887, 1182),
#   (174, 179),
#   (233, 238),
#   (154, 167),
#   (881, 1174),
#   (954, 838),
#   (250, 250),
#   (350, 350),
#   (1324, 1420),
#   (848, 941),
#   (800, 800),
#   (936, 826)],
#  'Caterpie': [(520, 520),
#   (77, 76),
#   (193, 186),
#   (960, 989),
#   (181, 168),
#   (224, 224),
#   (174, 185),
#   (308, 318),
#   (768, 761),
#   (500, 473),
#   (240, 210),
#   (776, 757),
#   (150, 200),
#   (166, 178),
#   (680, 900),
#   (897, 890),
#   (300, 300),
#   (396, 374),
#   (424, 486),
#   (206, 202),
#   (894, 894),
#   (250, 250),
#   (300, 300),
#   (450, 503),
#   (247, 247),
#   (206, 206),
#   (762, 790),
#   (83, 94),
#   (831, 900),
#   (2592, 1728),
#   (670, 670),
#   (800, 800),
#   (300, 300),
#   (367, 500),
#   (222, 225),
#   (137, 139),
#   (600, 601)],
#  'Chansey': [(69, 69),
#   (285, 261),
#   (834, 834),
#   (776, 873),
#   (206, 206),
#   (260, 256),
#   (389, 389),
#   (720, 785),
#   (312, 317),
#   (154, 181),
#   (429, 429),
#   (215, 215),
#   (571, 571),
#   (1500, 1500),
#   (503, 539),
#   (267, 300),
#   (240, 210),
#   (171, 171),
#   (881, 893),
#   (1188, 1377),
#   (328, 320),
#   (256, 256),
#   (179, 179),
#   (250, 250),
#   (58, 58),
#   (188, 188),
#   (285, 285),
#   (234, 234),
#   (881, 886),
#   (235, 235),
#   (546, 600),
#   (166, 166),
#   (388, 390),
#   (202, 202),
#   (230, 210),
#   (700, 702),
#   (476, 481),
#   (250, 250),
#   (615, 615),
#   (450, 458),
#   (497, 497),
#   (137, 137),
#   (349, 386)],
#  'Charizard': [(248, 248),
#   (800, 800),
#   (582, 597),
#   (447, 447),
#   (1869, 1869),
#   (872, 872),
#   (800, 800),
#   (1500, 1500),
#   (983, 988),
#   (543, 543),
#   (1286, 1273),
#   (351, 348),
#   (600, 600),
#   (278, 281),
#   (777, 777),
#   (795, 900),
#   (320, 320),
#   (475, 475),
#   (600, 613),
#   (355, 355),
#   (427, 427),
#   (540, 548),
#   (300, 297),
#   (243, 243),
#   (256, 256),
#   (1671, 1675),
#   (672, 668),
#   (671, 685),
#   (1200, 1185),
#   (683, 688),
#   (1478, 1601),
#   (200, 199),
#   (1077, 1095),
#   (198, 203),
#   (799, 800)],
#  'Charmander': [(842, 900),
#   (837, 828),
#   (862, 817),
#   (737, 702),
#   (1155, 1024),
#   (894, 894),
#   (1378, 1269),
#   (856, 834),
#   (878, 816),
#   (718, 718),
#   (620, 564),
#   (2293, 2293),
#   (993, 924),
#   (892, 843),
#   (884, 868),
#   (747, 686),
#   (767, 738),
#   (902, 897),
#   (849, 824),
#   (932, 932),
#   (911, 844),
#   (800, 773),
#   (298, 298),
#   (540, 540),
#   (894, 894),
#   (899, 850),
#   (1029, 1000),
#   (644, 600),
#   (453, 420),
#   (894, 894),
#   (958, 834),
#   (684, 623),
#   (896, 891),
#   (842, 842),
#   (932, 858),
#   (250, 250),
#   (707, 706),
#   (1311, 1269),
#   (192, 173),
#   (847, 813),
#   (401, 412),
#   (469, 468),
#   (192, 192),
#   (205, 205),
#   (434, 400),
#   (152, 152),
#   (700, 700),
#   (842, 949),
#   (800, 709),
#   (421, 421),
#   (280, 270)],
#  'Charmeleon': [(592, 568),
#   (303, 303),
#   (267, 255),
#   (720, 735),
#   (854, 847),
#   (137, 141),
#   (687, 687),
#   (678, 642),
#   (498, 496),
#   (304, 299),
#   (366, 373),
#   (769, 736),
#   (235, 235),
#   (894, 894),
#   (588, 580),
#   (712, 716),
#   (233, 210),
#   (511, 503),
#   (188, 188),
#   (158, 158),
#   (199, 199),
#   (1154, 1154),
#   (172, 172),
#   (250, 250),
#   (772, 772),
#   (590, 590),
#   (586, 562),
#   (240, 260),
#   (300, 300),
#   (350, 350),
#   (147, 147),
#   (623, 623),
#   (981, 980),
#   (511, 511),
#   (768, 741),
#   (726, 726),
#   (300, 300),
#   (1074, 1082),
#   (107, 107),
#   (141, 145),
#   (815, 807),
#   (599, 578),
#   (368, 381),
#   (448, 448),
#   (234, 238),
#   (234, 234)],
#  'Clefable': [(400, 400),
#   (351, 367),
#   (279, 275),
#   (740, 753),
#   (829, 839),
#   (563, 565),
#   (1400, 1500),
#   (290, 300),
#   (435, 450),
#   (1906, 1971),
#   (250, 250),
#   (161, 163),
#   (208, 208),
#   (191, 191),
#   (666, 666),
#   (894, 894),
#   (254, 260),
#   (440, 440),
#   (741, 741),
#   (240, 255),
#   (132, 132),
#   (300, 297),
#   (214, 214),
#   (283, 300),
#   (369, 369),
#   (574, 574),
#   (125, 125),
#   (555, 542),
#   (211, 211),
#   (449, 454),
#   (78, 78),
#   (179, 179),
#   (773, 862),
#   (394, 399),
#   (1000, 1000),
#   (230, 230),
#   (211, 211),
#   (276, 270)],
#  'Clefairy': [(230, 245),
#   (140, 140),
#   (450, 450),
#   (881, 938),
#   (280, 275),
#   (151, 151),
#   (215, 215),
#   (773, 754),
#   (300, 293),
#   (500, 500),
#   (320, 345),
#   (279, 300),
#   (234, 234),
#   (250, 250),
#   (520, 535),
#   (383, 408),
#   (200, 200),
#   (753, 755),
#   (431, 431),
#   (550, 565),
#   (500, 500),
#   (114, 114),
#   (210, 216),
#   (350, 350),
#   (226, 226),
#   (172, 172),
#   (159, 159),
#   (776, 776),
#   (250, 250),
#   (340, 320),
#   (451, 432),
#   (290, 300),
#   (400, 400),
#   (284, 300),
#   (810, 810),
#   (151, 151),
#   (198, 198),
#   (235, 235),
#   (868, 899),
#   (420, 420),
#   (200, 200),
#   (1500, 1500),
#   (103, 103),
#   (475, 475),
#   (1500, 1500),
#   (51, 51)],
#  'Cloyster': [(900, 900),
#   (600, 600),
#   (256, 256),
#   (315, 313),
#   (288, 300),
#   (500, 496),
#   (1710, 1710),
#   (140, 140),
#   (144, 144),
#   (358, 358),
#   (185, 185),
#   (280, 280),
#   (500, 484),
#   (460, 461),
#   (251, 251),
#   (300, 300),
#   (723, 723),
#   (309, 313),
#   (764, 772),
#   (175, 175),
#   (874, 891),
#   (881, 893),
#   (505, 505),
#   (249, 249),
#   (286, 300),
#   (160, 160),
#   (2629, 2629),
#   (192, 192),
#   (800, 800),
#   (213, 213),
#   (500, 360),
#   (250, 250),
#   (184, 198),
#   (183, 183),
#   (339, 342),
#   (230, 230),
#   (775, 807),
#   (279, 279),
#   (208, 208),
#   (235, 235),
#   (677, 680),
#   (502, 502),
#   (598, 598),
#   (479, 480),
#   (875, 889),
#   (720, 720),
#   (481, 481),
#   (446, 446)],
#  'Cubone': [(484, 484),
#   (565, 565),
#   (383, 337),
#   (347, 347),
#   (344, 344),
#   (138, 138),
#   (141, 143),
#   (800, 800),
#   (290, 290),
#   (1535, 1535),
#   (986, 993),
#   (887, 900),
#   (559, 566),
#   (126, 126),
#   (250, 250),
#   (245, 245),
#   (877, 877),
#   (210, 210),
#   (450, 450),
#   (295, 295),
#   (230, 210),
#   (600, 600),
#   (116, 116),
#   (551, 551),
#   (169, 169),
#   (175, 175),
#   (517, 516),
#   (300, 300),
#   (475, 475),
#   (286, 286),
#   (848, 850),
#   (800, 800),
#   (566, 566),
#   (800, 800),
#   (131, 131),
#   (784, 770),
#   (843, 855),
#   (166, 166),
#   (865, 865),
#   (1200, 1200)],
#  'Dewgong': [(191, 191),
#   (1080, 1094),
#   (120, 120),
#   (133, 133),
#   (300, 300),
#   (184, 184),
#   (1077, 1088),
#   (559, 561),
#   (440, 447),
#   (183, 183),
#   (144, 144),
#   (600, 600),
#   (594, 600),
#   (181, 181),
#   (193, 193),
#   (600, 600),
#   (163, 163),
#   (447, 447),
#   (199, 199),
#   (586, 586),
#   (800, 858),
#   (212, 213),
#   (194, 194),
#   (800, 800),
#   (789, 800),
#   (1293, 1294),
#   (567, 567),
#   (301, 300),
#   (250, 250),
#   (120, 120),
#   (1722, 1720),
#   (179, 179),
#   (117, 117),
#   (172, 172),
#   (800, 800),
#   (940, 1002),
#   (573, 573),
#   (896, 896),
#   (614, 614),
#   (1438, 1432),
#   (475, 475),
#   (293, 290),
#   (879, 879)],
#  'Diglett': [(175, 178),
#   (173, 173),
#   (827, 827),
#   (480, 500),
#   (278, 278),
#   (175, 175),
#   (254, 255),
#   (300, 298),
#   (475, 475),
#   (323, 320),
#   (250, 250),
#   (121, 121),
#   (196, 201),
#   (173, 188),
#   (143, 143),
#   (112, 113),
#   (184, 184),
#   (308, 308),
#   (153, 153),
#   (285, 285),
#   (122, 132),
#   (155, 155),
#   (197, 197),
#   (558, 554),
#   (252, 252),
#   (256, 256),
#   (194, 194),
#   (303, 303),
#   (405, 406),
#   (222, 222),
#   (762, 770),
#   (328, 329),
#   (579, 611),
#   (235, 237),
#   (235, 235),
#   (530, 530),
#   (430, 430),
#   (501, 480),
#   (224, 224)],
#  'Ditto': [(719, 730),
#   (469, 469),
#   (294, 294),
#   (250, 250),
#   (714, 714),
#   (545, 552),
#   (147, 147),
#   (113, 113),
#   (318, 350),
#   (475, 475),
#   (417, 421),
#   (670, 670),
#   (776, 898),
#   (611, 614),
#   (255, 255),
#   (71, 71),
#   (1500, 1500),
#   (499, 501),
#   (344, 370),
#   (143, 143),
#   (230, 210),
#   (792, 805),
#   (570, 571),
#   (243, 245),
#   (126, 126),
#   (547, 547),
#   (804, 788),
#   (159, 160),
#   (259, 260),
#   (875, 890),
#   (251, 251),
#   (140, 140),
#   (792, 792),
#   (404, 404),
#   (153, 153),
#   (344, 344),
#   (309, 309),
#   (1080, 1096),
#   (277, 277),
#   (184, 184)],
#  'Dodrio': [(286, 292),
#   (129, 129),
#   (503, 502),
#   (114, 116),
#   (711, 728),
#   (357, 348),
#   (246, 243),
#   (138, 138),
#   (203, 203),
#   (493, 489),
#   (300, 300),
#   (260, 261),
#   (154, 154),
#   (676, 679),
#   (308, 308),
#   (250, 250),
#   (433, 433),
#   (226, 226),
#   (250, 250),
#   (158, 158),
#   (400, 400),
#   (566, 563),
#   (227, 227),
#   (205, 205),
#   (176, 176),
#   (252, 260),
#   (114, 117),
#   (187, 187),
#   (256, 256),
#   (865, 865),
#   (812, 820),
#   (717, 717),
#   (184, 184),
#   (719, 721),
#   (349, 349),
#   (533, 525),
#   (882, 882),
#   (768, 762),
#   (800, 800)],
#  'Doduo': [(250, 250),
#   (254, 254),
#   (130, 130),
#   (222, 222),
#   (474, 474),
#   (232, 232),
#   (196, 195),
#   (300, 300),
#   (748, 710),
#   (1071, 1071),
#   (558, 558),
#   (216, 200),
#   (402, 400),
#   (403, 403),
#   (287, 286),
#   (210, 210),
#   (250, 250),
#   (650, 650),
#   (500, 500),
#   (653, 653),
#   (485, 485),
#   (220, 220),
#   (490, 490),
#   (178, 178),
#   (389, 389),
#   (881, 891),
#   (800, 800),
#   (120, 120),
#   (300, 300),
#   (252, 252),
#   (509, 509),
#   (438, 438),
#   (193, 193),
#   (637, 639),
#   (773, 766)],
#  'Dragonair': [(709, 709),
#   (300, 300),
#   (250, 250),
#   (1500, 1500),
#   (635, 642),
#   (300, 300),
#   (670, 670),
#   (300, 269),
#   (410, 410),
#   (1500, 1500),
#   (850, 856),
#   (351, 353),
#   (250, 250),
#   (232, 232),
#   (1200, 1200),
#   (191, 191),
#   (908, 879),
#   (774, 774),
#   (463, 463),
#   (1200, 1200),
#   (256, 256),
#   (600, 600),
#   (213, 212),
#   (222, 222),
#   (894, 894),
#   (772, 759),
#   (482, 482),
#   (235, 235),
#   (719, 725),
#   (1067, 1082),
#   (163, 163),
#   (589, 585),
#   (240, 260),
#   (622, 612),
#   (800, 778),
#   (118, 118),
#   (253, 253),
#   (245, 245),
#   (647, 600),
#   (526, 543),
#   (878, 881),
#   (701, 705)],
#  'Dragonite': [(127, 126),
#   (140, 142),
#   (250, 250),
#   (432, 438),
#   (578, 580),
#   (586, 586),
#   (450, 456),
#   (428, 436),
#   (918, 912),
#   (199, 199),
#   (671, 671),
#   (223, 223),
#   (785, 790),
#   (256, 256),
#   (234, 234),
#   (193, 193),
#   (299, 300),
#   (158, 158),
#   (779, 803),
#   (724, 724),
#   (1639, 1639),
#   (713, 717),
#   (238, 236),
#   (110, 110),
#   (250, 250),
#   (596, 591),
#   (876, 879),
#   (186, 186),
#   (606, 606),
#   (602, 594),
#   (740, 746),
#   (359, 356),
#   (360, 364),
#   (512, 512),
#   (124, 126),
#   (636, 641),
#   (409, 409),
#   (870, 878),
#   (420, 420),
#   (2452, 2473),
#   (208, 208),
#   (698, 699),
#   (250, 250),
#   (866, 860),
#   (434, 434),
#   (646, 646),
#   (398, 392),
#   (206, 206)],
#  'Dratini': [(720, 732),
#   (158, 158),
#   (176, 176),
#   (266, 236),
#   (167, 167),
#   (247, 247),
#   (272, 272),
#   (400, 409),
#   (800, 800),
#   (232, 232),
#   (1568, 1625),
#   (158, 158),
#   (450, 450),
#   (273, 269),
#   (466, 466),
#   (244, 245),
#   (620, 600),
#   (96, 96),
#   (284, 289),
#   (600, 600),
#   (714, 714),
#   (235, 235),
#   (240, 247),
#   (800, 800),
#   (995, 995),
#   (359, 360)],
#  'Drowzee': [(800, 800),
#   (231, 231),
#   (400, 399),
#   (203, 203),
#   (229, 229),
#   (316, 316),
#   (140, 140),
#   (491, 491),
#   (139, 127),
#   (602, 600),
#   (128, 132),
#   (300, 298),
#   (151, 151),
#   (881, 887),
#   (342, 342),
#   (181, 181),
#   (296, 300),
#   (567, 562),
#   (228, 228),
#   (235, 235),
#   (642, 570),
#   (120, 120),
#   (574, 579),
#   (156, 156),
#   (500, 500),
#   (500, 500),
#   (151, 151),
#   (720, 729),
#   (250, 250),
#   (243, 242),
#   (200, 200),
#   (174, 176),
#   (256, 256),
#   (112, 117),
#   (329, 331),
#   (685, 711),
#   (353, 353),
#   (239, 239),
#   (185, 185)],
#  'Dugtrio': [(180, 180),
#   (506, 513),
#   (260, 262),
#   (221, 221),
#   (300, 300),
#   (703, 698),
#   (600, 600),
#   (133, 136),
#   (722, 722),
#   (191, 191),
#   (1500, 1500),
#   (759, 759),
#   (300, 270),
#   (729, 741),
#   (165, 165),
#   (281, 300),
#   (345, 345),
#   (173, 173),
#   (198, 198),
#   (347, 347),
#   (477, 472),
#   (864, 864),
#   (228, 228),
#   (331, 331),
#   (141, 149),
#   (801, 801),
#   (650, 650),
#   (650, 650),
#   (738, 1080),
#   (719, 722),
#   (121, 121),
#   (157, 157),
#   (250, 250),
#   (211, 215),
#   (326, 320),
#   (404, 404),
#   (898, 898),
#   (420, 420),
#   (378, 378),
#   (500, 500),
#   (334, 336),
#   (398, 399),
#   (387, 437),
#   (731, 748),
#   (700, 711),
#   (131, 131),
#   (347, 350),
#   (300, 284),
#   (305, 305),
#   (366, 366),
#   (216, 216)],
#  'Eevee': [(694, 540),
#   (557, 536),
#   (300, 243),
#   (505, 534),
#   (524, 425),
#   (355, 355),
#   (256, 251),
#   (1142, 1165),
#   (336, 315),
#   (244, 280),
#   (432, 768),
#   (126, 132),
#   (300, 265),
#   (349, 620),
#   (283, 272),
#   (337, 287),
#   (204, 221),
#   (485, 583),
#   (640, 1024),
#   (684, 900),
#   (679, 616),
#   (216, 195),
#   (308, 335),
#   (300, 300),
#   (315, 294),
#   (2015, 2067),
#   (458, 458),
#   (720, 1280),
#   (938, 625),
#   (821, 974),
#   (450, 420),
#   (942, 848),
#   (1500, 1500),
#   (294, 285),
#   (335, 264),
#   (250, 250),
#   (894, 894)],
#  'Ekans': [(113, 113),
#   (94, 94),
#   (874, 889),
#   (851, 851),
#   (181, 181),
#   (452, 452),
#   (156, 156),
#   (300, 300),
#   (388, 395),
#   (250, 250),
#   (248, 248),
#   (1088, 1088),
#   (1061, 1061),
#   (702, 703),
#   (700, 700),
#   (188, 192),
#   (297, 300),
#   (475, 494),
#   (833, 860),
#   (881, 902),
#   (145, 145),
#   (410, 434),
#   (315, 316),
#   (184, 184),
#   (720, 1280),
#   (597, 598),
#   (263, 267),
#   (457, 457),
#   (410, 414),
#   (800, 800),
#   (256, 256),
#   (232, 232),
#   (113, 113),
#   (909, 901),
#   (643, 648),
#   (104, 104)],
#  'Electabuzz': [(1007, 1007),
#   (1386, 1440),
#   (872, 875),
#   (153, 153),
#   (240, 210),
#   (315, 315),
#   (575, 577),
#   (66, 66),
#   (300, 305),
#   (1080, 1093),
#   (664, 664),
#   (262, 260),
#   (287, 287),
#   (823, 835),
#   (229, 229),
#   (880, 887),
#   (142, 142),
#   (250, 250),
#   (183, 183),
#   (170, 170),
#   (306, 299),
#   (186, 186),
#   (493, 481),
#   (768, 776),
#   (765, 765),
#   (178, 165),
#   (150, 150),
#   (779, 779),
#   (502, 504),
#   (223, 223),
#   (573, 566),
#   (1267, 1267),
#   (177, 177),
#   (190, 190),
#   (605, 599),
#   (444, 444),
#   (233, 233),
#   (444, 445),
#   (292, 295),
#   (676, 682),
#   (556, 556)],
#  'Electrode': [(299, 299),
#   (1019, 1019),
#   (157, 156),
#   (256, 256),
#   (441, 441),
#   (64, 64),
#   (386, 386),
#   (246, 246),
#   (792, 792),
#   (202, 202),
#   (1068, 1068),
#   (337, 337),
#   (111, 111),
#   (517, 517),
#   (141, 141),
#   (578, 583),
#   (527, 527),
#   (572, 572),
#   (612, 612),
#   (484, 484),
#   (733, 733),
#   (291, 293),
#   (402, 402),
#   (133, 133),
#   (70, 70),
#   (204, 204),
#   (186, 186),
#   (871, 871),
#   (350, 346),
#   (184, 185),
#   (234, 234),
#   (281, 281),
#   (116, 116),
#   (192, 196),
#   (533, 533),
#   (170, 170),
#   (300, 300),
#   (800, 800),
#   (250, 250),
#   (300, 299),
#   (875, 913),
#   (316, 316),
#   (736, 736),
#   (231, 231),
#   (250, 250),
#   (286, 286),
#   (410, 405),
#   (188, 188),
#   (231, 231),
#   (322, 325),
#   (1440, 1440)],
#  'Exeggcute': [(414, 414),
#   (395, 398),
#   (170, 176),
#   (115, 115),
#   (109, 109),
#   (416, 412),
#   (234, 237),
#   (800, 800),
#   (284, 284),
#   (748, 758),
#   (160, 160),
#   (657, 657),
#   (208, 208),
#   (869, 869),
#   (280, 280),
#   (188, 188),
#   (300, 300),
#   (342, 342),
#   (141, 154),
#   (1016, 1000),
#   (845, 861),
#   (180, 180),
#   (381, 381),
#   (202, 202),
#   (261, 261),
#   (307, 307),
#   (1414, 1414),
#   (191, 191),
#   (235, 235),
#   (500, 500),
#   (217, 217),
#   (768, 776),
#   (122, 122),
#   (250, 250),
#   (229, 233),
#   (688, 688),
#   (730, 730),
#   (360, 386),
#   (771, 796),
#   (256, 256),
#   (1109, 1200),
#   (474, 474),
#   (196, 196),
#   (236, 236),
#   (480, 485),
#   (1003, 1003)],
#  'Exeggutor': [(627, 627),
#   (466, 466),
#   (183, 191),
#   (250, 250),
#   (232, 232),
#   (231, 225),
#   (425, 424),
#   (256, 256),
#   (800, 800),
#   (199, 199),
#   (256, 256),
#   (968, 968),
#   (200, 197),
#   (199, 199),
#   (256, 256),
#   (1121, 1146),
#   (209, 209),
#   (612, 612),
#   (323, 332),
#   (1500, 1500),
#   (175, 183),
#   (678, 678),
#   (162, 162),
#   (133, 133),
#   (800, 800),
#   (992, 992),
#   (1050, 1050),
#   (250, 257),
#   (187, 187),
#   (280, 280),
#   (298, 300),
#   (442, 448),
#   (218, 221),
#   (324, 355),
#   (614, 614),
#   (300, 300),
#   (298, 299),
#   (266, 292),
#   (930, 930),
#   (335, 335),
#   (1118, 1116),
#   (427, 428),
#   (298, 296),
#   (2343, 2388),
#   (565, 568),
#   (813, 813),
#   (256, 256),
#   (500, 500),
#   (720, 759),
#   (705, 730)],
#  'Farfetchd': [(221, 221),
#   (262, 262),
#   (908, 908),
#   (881, 910),
#   (733, 733),
#   (258, 258),
#   (300, 300),
#   (391, 391),
#   (272, 271),
#   (480, 482),
#   (190, 190),
#   (124, 124),
#   (260, 257),
#   (742, 736),
#   (367, 370),
#   (630, 633),
#   (525, 524),
#   (363, 363),
#   (210, 199),
#   (1792, 1818),
#   (177, 177),
#   (512, 512),
#   (485, 485),
#   (220, 210),
#   (847, 850),
#   (172, 172),
#   (300, 282),
#   (471, 466),
#   (327, 327),
#   (696, 696),
#   (245, 245),
#   (175, 175),
#   (277, 236),
#   (580, 600),
#   (248, 248),
#   (435, 404),
#   (344, 344),
#   (63, 63),
#   (244, 244),
#   (313, 313),
#   (256, 256),
#   (236, 236),
#   (867, 867),
#   (528, 528),
#   (542, 542),
#   (235, 235),
#   (308, 308),
#   (250, 250)],
#  'Fearow': [(219, 219),
#   (578, 581),
#   (600, 614),
#   (602, 609),
#   (120, 121),
#   (418, 423),
#   (141, 145),
#   (280, 280),
#   (802, 798),
#   (231, 232),
#   (354, 354),
#   (771, 773),
#   (250, 250),
#   (945, 968),
#   (161, 161),
#   (291, 291),
#   (598, 598),
#   (825, 825),
#   (236, 238),
#   (878, 886),
#   (634, 633),
#   (156, 157),
#   (256, 256),
#   (881, 889),
#   (224, 221),
#   (381, 386),
#   (360, 363),
#   (420, 420),
#   (250, 250),
#   (242, 242),
#   (506, 506),
#   (191, 191),
#   (763, 760),
#   (204, 204),
#   (933, 939),
#   (240, 245),
#   (303, 303),
#   (359, 359),
#   (209, 212),
#   (876, 887),
#   (599, 605),
#   (277, 277),
#   (300, 300),
#   (173, 174),
#   (309, 309),
#   (316, 317),
#   (151, 151),
#   (211, 209)],
#  'Flareon': [(857, 848),
#   (462, 500),
#   (1500, 1500),
#   (219, 219),
#   (1666, 1673),
#   (562, 562),
#   (268, 268),
#   (497, 501),
#   (277, 277),
#   (416, 416),
#   (1658, 1656),
#   (881, 883),
#   (543, 538),
#   (367, 371),
#   (151, 151),
#   (789, 789),
#   (200, 200),
#   (308, 308),
#   (466, 466),
#   (232, 237),
#   (800, 800),
#   (501, 506),
#   (573, 583),
#   (571, 568),
#   (606, 606),
#   (247, 247),
#   (579, 582),
#   (1683, 1701),
#   (722, 744),
#   (500, 500),
#   (343, 343),
#   (331, 337),
#   (250, 250),
#   (355, 328),
#   (512, 473),
#   (799, 807),
#   (218, 218),
#   (630, 630),
#   (140, 144),
#   (160, 160),
#   (260, 263),
#   (1200, 1200),
#   (477, 484),
#   (570, 570),
#   (1218, 1142)],
#  'Gastly': [(300, 300),
#   (706, 706),
#   (579, 581),
#   (315, 315),
#   (250, 250),
#   (670, 670),
#   (325, 325),
#   (720, 740),
#   (478, 481),
#   (236, 236),
#   (773, 774),
#   (195, 196),
#   (599, 605),
#   (141, 153),
#   (905, 911),
#   (155, 155),
#   (432, 441),
#   (763, 768),
#   (731, 892),
#   (666, 684),
#   (300, 300),
#   (191, 191),
#   (357, 350),
#   (315, 315),
#   (353, 353),
#   (113, 113),
#   (718, 717),
#   (156, 156),
#   (646, 634),
#   (170, 174),
#   (600, 600),
#   (552, 564),
#   (733, 742),
#   (210, 210),
#   (128, 128),
#   (308, 313),
#   (820, 803),
#   (550, 550),
#   (250, 250),
#   (255, 251),
#   (256, 256),
#   (773, 774),
#   (680, 680),
#   (240, 240)],
#  'Gengar': [(350, 330),
#   (720, 755),
#   (700, 700),
#   (205, 220),
#   (393, 393),
#   (183, 178),
#   (223, 210),
#   (376, 376),
#   (266, 266),
#   (224, 224),
#   (726, 726),
#   (127, 127),
#   (750, 750),
#   (150, 153),
#   (256, 256),
#   (300, 300),
#   (1431, 1431),
#   (147, 147),
#   (600, 600),
#   (441, 440),
#   (720, 683),
#   (620, 638),
#   (300, 277),
#   (995, 995),
#   (266, 266),
#   (356, 356),
#   (602, 602),
#   (435, 435),
#   (300, 292),
#   (435, 440),
#   (776, 754),
#   (866, 866),
#   (669, 669),
#   (547, 572),
#   (881, 888),
#   (250, 250),
#   (552, 552),
#   (870, 871),
#   (192, 192),
#   (698, 698),
#   (600, 600),
#   (906, 915),
#   (690, 677),
#   (350, 350),
#   (376, 375),
#   (393, 393),
#   (1778, 1675),
#   (1500, 1500),
#   (328, 320)],
#  'Geodude': [(139, 155),
#   (868, 868),
#   (141, 151),
#   (349, 349),
#   (800, 800),
#   (192, 195),
#   (256, 256),
#   (207, 207),
#   (881, 921),
#   (598, 609),
#   (743, 752),
#   (614, 636),
#   (720, 723),
#   (115, 127),
#   (377, 383),
#   (360, 376),
#   (179, 179),
#   (182, 182),
#   (500, 500),
#   (219, 220),
#   (266, 272),
#   (703, 705),
#   (148, 148),
#   (377, 381),
#   (368, 371),
#   (590, 590),
#   (480, 481),
#   (716, 728),
#   (416, 416),
#   (250, 250),
#   (188, 188),
#   (458, 463),
#   (315, 315),
#   (201, 207),
#   (111, 116)],
#  'Gloom': [(300, 300),
#   (700, 700),
#   (333, 333),
#   (251, 251),
#   (300, 298),
#   (534, 500),
#   (375, 375),
#   (140, 140),
#   (800, 800),
#   (610, 603),
#   (630, 630),
#   (318, 381),
#   (149, 149),
#   (74, 74),
#   (144, 144),
#   (623, 623),
#   (1194, 1223),
#   (584, 592),
#   (633, 638),
#   (150, 152),
#   (240, 244),
#   (897, 890),
#   (303, 303),
#   (280, 280),
#   (363, 363),
#   (1500, 1500),
#   (259, 259),
#   (391, 395),
#   (266, 266),
#   (390, 390),
#   (478, 482),
#   (532, 537),
#   (184, 184),
#   (250, 250),
#   (604, 606),
#   (285, 300),
#   (195, 195),
#   (697, 736),
#   (338, 338),
#   (940, 940),
#   (140, 135),
#   (271, 258),
#   (1446, 1432),
#   (779, 722),
#   (501, 505),
#   (466, 466),
#   (160, 162),
#   (150, 154),
#   (881, 898)],
#  'Golbat': [(277, 277),
#   (203, 203),
#   (300, 300),
#   (400, 400),
#   (881, 901),
#   (303, 306),
#   (291, 296),
#   (119, 120),
#   (404, 404),
#   (225, 227),
#   (223, 223),
#   (379, 379),
#   (661, 661),
#   (244, 250),
#   (881, 897),
#   (324, 320),
#   (574, 581),
#   (215, 215),
#   (1020, 1020),
#   (250, 250),
#   (800, 800),
#   (255, 255),
#   (600, 600),
#   (250, 250),
#   (158, 158),
#   (261, 269),
#   (256, 256),
#   (240, 243),
#   (582, 588),
#   (480, 484),
#   (368, 381),
#   (360, 371),
#   (139, 141),
#   (281, 281),
#   (868, 861),
#   (462, 462),
#   (349, 349),
#   (1056, 1063),
#   (781, 787),
#   (206, 206),
#   (881, 900),
#   (258, 258),
#   (568, 578),
#   (417, 417),
#   (128, 128),
#   (638, 645),
#   (238, 244),
#   (152, 152)],
#  'Goldeen': [(720, 735),
#   (215, 214),
#   (250, 250),
#   (876, 877),
#   (200, 200),
#   (578, 584),
#   (979, 1024),
#   (207, 210),
#   (886, 886),
#   (702, 702),
#   (186, 186),
#   (175, 177),
#   (423, 420),
#   (602, 599),
#   (232, 232),
#   (401, 398),
#   (178, 178),
#   (196, 196),
#   (152, 159),
#   (310, 310),
#   (250, 250),
#   (600, 600),
#   (152, 152),
#   (235, 235),
#   (742, 742),
#   (213, 213),
#   (1232, 1232),
#   (531, 532),
#   (528, 519),
#   (149, 149),
#   (250, 250),
#   (240, 233),
#   (338, 338),
#   (213, 210),
#   (878, 879),
#   (139, 139),
#   (235, 239),
#   (296, 300),
#   (194, 194),
#   (290, 287),
#   (178, 178),
#   (70, 70),
#   (200, 200),
#   (320, 320),
#   (205, 205),
#   (430, 440),
#   (372, 373)],
#  'Golduck': [(770, 770),
#   (800, 800),
#   (193, 193),
#   (800, 800),
#   (881, 937),
#   (139, 139),
#   (295, 300),
#   (233, 235),
#   (202, 202),
#   (786, 784),
#   (245, 236),
#   (564, 564),
#   (297, 297),
#   (1200, 1200),
#   (502, 508),
#   (243, 243),
#   (142, 142),
#   (170, 154),
#   (875, 875),
#   (590, 590),
#   (333, 333),
#   (879, 885),
#   (113, 110),
#   (721, 721),
#   (171, 171),
#   (707, 698),
#   (350, 327),
#   (193, 193),
#   (293, 293),
#   (223, 220),
#   (272, 272),
#   (347, 347),
#   (149, 149),
#   (200, 200),
#   (362, 362),
#   (607, 612),
#   (357, 358),
#   (427, 427),
#   (359, 364),
#   (844, 844),
#   (272, 272),
#   (824, 824),
#   (280, 280),
#   (210, 210),
#   (184, 184),
#   (311, 307)],
#  'Golem': [(194, 194),
#   (186, 186),
#   (229, 235),
#   (270, 263),
#   (755, 755),
#   (120, 120),
#   (325, 337),
#   (175, 175),
#   (875, 879),
#   (295, 294),
#   (191, 191),
#   (556, 556),
#   (299, 305),
#   (600, 611),
#   (506, 506),
#   (164, 163),
#   (154, 155),
#   (302, 302),
#   (138, 138),
#   (222, 222),
#   (138, 192),
#   (1167, 1225),
#   (1076, 1068),
#   (830, 830),
#   (677, 685),
#   (274, 274),
#   (163, 163),
#   (677, 677),
#   (431, 431),
#   (202, 202),
#   (223, 223),
#   (800, 800),
#   (250, 250),
#   (105, 105),
#   (285, 288),
#   (188, 188),
#   (510, 512),
#   (611, 659),
#   (360, 364),
#   (600, 600),
#   (854, 915),
#   (300, 298),
#   (319, 319),
#   (160, 160),
#   (161, 161),
#   (869, 869)],
#  'Graveler': [(303, 309),
#   (600, 600),
#   (140, 140),
#   (360, 369),
#   (781, 787),
#   (362, 368),
#   (395, 395),
#   (124, 125),
#   (367, 367),
#   (881, 884),
#   (221, 221),
#   (500, 500),
#   (219, 219),
#   (566, 549),
#   (921, 921),
#   (142, 142),
#   (1326, 1326),
#   (444, 444),
#   (250, 250),
#   (245, 247),
#   (415, 420),
#   (250, 250),
#   (300, 300),
#   (630, 632),
#   (901, 901),
#   (192, 192),
#   (800, 800),
#   (167, 167),
#   (187, 187),
#   (196, 196),
#   (185, 185),
#   (128, 128),
#   (878, 885),
#   (875, 880),
#   (305, 305),
#   (184, 189),
#   (652, 650),
#   (120, 120),
#   (256, 256)],
#  'Grimer': [(719, 729),
#   (1000, 1000),
#   (634, 728),
#   (557, 557),
#   (262, 262),
#   (94, 94),
#   (709, 718),
#   (156, 156),
#   (343, 343),
#   (250, 250),
#   (715, 734),
#   (57, 57),
#   (93, 93),
#   (631, 700),
#   (334, 334),
#   (800, 800),
#   (231, 232),
#   (520, 522),
#   (620, 605),
#   (250, 250),
#   (207, 213),
#   (175, 175),
#   (214, 214),
#   (183, 183),
#   (180, 180),
#   (277, 277),
#   (900, 900),
#   (473, 473),
#   (410, 410),
#   (165, 174),
#   (608, 608),
#   (920, 920),
#   (132, 132),
#   (454, 454),
#   (152, 152),
#   (158, 158),
#   (314, 314),
#   (254, 254),
#   (160, 161),
#   (323, 323),
#   (488, 488),
#   (166, 166),
#   (342, 342),
#   (214, 219)],
#  'Growlithe': [(480, 483),
#   (397, 400),
#   (222, 217),
#   (136, 152),
#   (195, 195),
#   (700, 700),
#   (297, 307),
#   (880, 885),
#   (370, 370),
#   (327, 327),
#   (1500, 1500),
#   (434, 435),
#   (1080, 1093),
#   (110, 111),
#   (165, 165),
#   (478, 480),
#   (282, 282),
#   (138, 138),
#   (250, 250),
#   (184, 184),
#   (746, 746),
#   (873, 826),
#   (84, 84),
#   (245, 245),
#   (540, 500),
#   (406, 400),
#   (228, 228),
#   (244, 242),
#   (214, 223),
#   (769, 773),
#   (814, 798),
#   (234, 234),
#   (881, 887),
#   (709, 709),
#   (289, 287),
#   (179, 179),
#   (576, 560),
#   (454, 458),
#   (231, 231),
#   (805, 823),
#   (183, 183),
#   (704, 704),
#   (102, 102),
#   (178, 178)],
#  'Gyarados': [(262, 262),
#   (640, 640),
#   (790, 790),
#   (640, 640),
#   (470, 470),
#   (580, 586),
#   (208, 208),
#   (640, 594),
#   (387, 396),
#   (1199, 1202),
#   (457, 457),
#   (1202, 1208),
#   (738, 738),
#   (1080, 1089),
#   (246, 246),
#   (644, 638),
#   (316, 316),
#   (892, 892),
#   (608, 608),
#   (446, 446),
#   (476, 476),
#   (488, 488),
#   (176, 172),
#   (446, 444),
#   (941, 951),
#   (228, 227),
#   (168, 168),
#   (573, 573),
#   (239, 236),
#   (256, 256),
#   (217, 221),
#   (722, 722),
#   (632, 638),
#   (901, 901),
#   (185, 185),
#   (213, 213),
#   (250, 250),
#   (246, 244),
#   (430, 428),
#   (600, 600),
#   (710, 719),
#   (224, 224),
#   (219, 208),
#   (475, 472),
#   (175, 175),
#   (675, 677)],
#  'Haunter': [(936, 971),
#   (800, 800),
#   (625, 625),
#   (415, 415),
#   (547, 531),
#   (1080, 1105),
#   (725, 725),
#   (247, 244),
#   (196, 196),
#   (519, 530),
#   (345, 345),
#   (323, 337),
#   (904, 866),
#   (740, 740),
#   (146, 143),
#   (300, 272),
#   (442, 442),
#   (739, 739),
#   (254, 254),
#   (423, 428),
#   (210, 210),
#   (623, 623),
#   (721, 717),
#   (83, 83),
#   (880, 880),
#   (473, 482),
#   (600, 600),
#   (153, 153),
#   (2000, 2000),
#   (500, 500),
#   (264, 264),
#   (256, 256),
#   (373, 378),
#   (203, 206),
#   (165, 165),
#   (250, 250),
#   (561, 561),
#   (2345, 2322),
#   (250, 250),
#   (880, 885),
#   (474, 474),
#   (711, 715),
#   (207, 207),
#   (713, 713),
#   (286, 286),
#   (666, 666),
#   (112, 113),
#   (155, 155)],
#  'Hitmonchan': [(319, 319),
#   (176, 176),
#   (358, 343),
#   (443, 445),
#   (319, 319),
#   (1052, 1059),
#   (75, 75),
#   (154, 157),
#   (105, 105),
#   (345, 344),
#   (868, 868),
#   (754, 754),
#   (250, 250),
#   (200, 200),
#   (240, 241),
#   (325, 300),
#   (232, 232),
#   (187, 184),
#   (800, 800),
#   (598, 596),
#   (215, 215),
#   (736, 736),
#   (691, 691),
#   (315, 315),
#   (744, 744),
#   (1000, 1000),
#   (202, 202),
#   (392, 392),
#   (199, 199),
#   (655, 655),
#   (635, 597),
#   (143, 143),
#   (169, 172),
#   (180, 184),
#   (233, 233),
#   (267, 267),
#   (691, 681),
#   (848, 848),
#   (868, 876),
#   (244, 244),
#   (135, 135),
#   (160, 160),
#   (196, 196),
#   (95, 95),
#   (739, 742),
#   (106, 106),
#   (137, 137)],
#  'Hitmonlee': [(272, 272),
#   (709, 713),
#   (1089, 1089),
#   (771, 771),
#   (180, 180),
#   (352, 328),
#   (256, 256),
#   (158, 156),
#   (431, 432),
#   (352, 352),
#   (256, 256),
#   (121, 121),
#   (222, 221),
#   (328, 328),
#   (250, 250),
#   (876, 897),
#   (754, 754),
#   (249, 249),
#   (168, 168),
#   (573, 573),
#   (708, 708),
#   (90, 90),
#   (140, 140),
#   (879, 880),
#   (881, 893),
#   (187, 187),
#   (234, 234),
#   (886, 901),
#   (773, 773),
#   (483, 483),
#   (320, 318),
#   (619, 609),
#   (581, 581),
#   (141, 148),
#   (877, 878),
#   (563, 569),
#   (312, 304),
#   (856, 856),
#   (174, 177),
#   (250, 250),
#   (169, 169),
#   (338, 291),
#   (170, 105),
#   (1448, 1428),
#   (669, 671),
#   (656, 800),
#   (277, 300),
#   (500, 614)],
#  'Horsea': [(308, 308),
#   (219, 210),
#   (193, 193),
#   (450, 423),
#   (331, 331),
#   (334, 315),
#   (159, 159),
#   (696, 696),
#   (600, 600),
#   (800, 800),
#   (135, 135),
#   (800, 800),
#   (576, 576),
#   (153, 153),
#   (118, 113),
#   (411, 411),
#   (89, 89),
#   (897, 891),
#   (501, 481),
#   (153, 153),
#   (739, 739),
#   (500, 500),
#   (114, 114),
#   (546, 546),
#   (235, 235),
#   (207, 207),
#   (854, 843),
#   (598, 598),
#   (592, 571),
#   (170, 170),
#   (300, 300),
#   (210, 212),
#   (335, 335),
#   (117, 117),
#   (500, 500),
#   (400, 400),
#   (712, 712),
#   (717, 717),
#   (474, 474),
#   (925, 900),
#   (189, 189),
#   (157, 157),
#   (400, 400),
#   (250, 250),
#   (372, 372),
#   (1000, 889),
#   (300, 266),
#   (115, 115),
#   (134, 133),
#   (881, 870),
#   (312, 312),
#   (662, 636),
#   (196, 182),
#   (239, 239)],
#  'Hypno': [(223, 223),
#   (170, 170),
#   (300, 281),
#   (603, 598),
#   (260, 260),
#   (213, 200),
#   (768, 790),
#   (517, 500),
#   (379, 379),
#   (441, 441),
#   (475, 475),
#   (1080, 1103),
#   (583, 583),
#   (874, 888),
#   (900, 850),
#   (809, 804),
#   (145, 145),
#   (776, 740),
#   (297, 297),
#   (868, 886),
#   (250, 250),
#   (169, 169),
#   (322, 319),
#   (186, 186),
#   (156, 156),
#   (333, 333),
#   (386, 386),
#   (622, 622),
#   (250, 250),
#   (549, 537),
#   (763, 763),
#   (255, 255),
#   (346, 346),
#   (630, 630),
#   (820, 821),
#   (339, 337),
#   (145, 145),
#   (202, 202),
#   (520, 529),
#   (125, 126),
#   (340, 340),
#   (169, 167),
#   (965, 958),
#   (166, 166),
#   (300, 300),
#   (139, 139),
#   (881, 881)],
#  'Ivysaur': [(363, 363),
#   (235, 235),
#   (796, 796),
#   (222, 222),
#   (835, 827),
#   (160, 160),
#   (173, 173),
#   (168, 168),
#   (250, 237),
#   (98, 100),
#   (169, 169),
#   (500, 500),
#   (368, 373),
#   (710, 749),
#   (881, 885),
#   (162, 162),
#   (500, 500),
#   (293, 314),
#   (155, 155),
#   (480, 480),
#   (702, 702),
#   (600, 600),
#   (780, 785),
#   (413, 414),
#   (1118, 1114),
#   (660, 664),
#   (200, 200),
#   (951, 951),
#   (606, 607),
#   (874, 868),
#   (292, 296),
#   (562, 567),
#   (336, 338),
#   (902, 886),
#   (761, 761),
#   (340, 340),
#   (881, 886),
#   (600, 614),
#   (84, 84),
#   (817, 831)],
#  'Jigglypuff': [(862, 858),
#   (195, 190),
#   (838, 838),
#   (711, 711),
#   (220, 220),
#   (789, 797),
#   (390, 368),
#   (600, 600),
#   (450, 450),
#   (465, 465),
#   (153, 153),
#   (226, 226),
#   (280, 280),
#   (900, 887),
#   (201, 201),
#   (221, 210),
#   (556, 556),
#   (886, 901),
#   (1002, 1024),
#   (1707, 1707),
#   (130, 130),
#   (300, 296),
#   (716, 721),
#   (2199, 2199),
#   (216, 216),
#   (331, 325),
#   (204, 204),
#   (592, 550),
#   (474, 474),
#   (448, 449),
#   (231, 231),
#   (661, 661),
#   (225, 225),
#   (277, 281),
#   (1410, 1393),
#   (136, 136),
#   (376, 403),
#   (350, 350),
#   (130, 119),
#   (734, 734),
#   (176, 180),
#   (134, 134),
#   (830, 813),
#   (868, 920),
#   (458, 458),
#   (250, 250)],
#  'Jolteon': [(663, 665),
#   (881, 905),
#   (1500, 1500),
#   (517, 500),
#   (881, 899),
#   (285, 285),
#   (133, 137),
#   (253, 253),
#   (778, 763),
#   (548, 548),
#   (805, 805),
#   (616, 621),
#   (499, 499),
#   (836, 853),
#   (878, 887),
#   (345, 354),
#   (457, 457),
#   (715, 718),
#   (782, 788),
#   (133, 133),
#   (368, 368),
#   (174, 174),
#   (179, 179),
#   (299, 300),
#   (121, 121),
#   (466, 466),
#   (599, 605),
#   (1294, 1300),
#   (276, 276),
#   (602, 602),
#   (190, 190),
#   (695, 714),
#   (182, 183),
#   (634, 634),
#   (1009, 1000),
#   (422, 422),
#   (87, 87),
#   (300, 267),
#   (300, 278),
#   (1225, 1201),
#   (404, 404),
#   (480, 470),
#   (176, 180),
#   (250, 250),
#   (667, 659),
#   (132, 132),
#   (1500, 1500),
#   (824, 824),
#   (706, 712),
#   (149, 151),
#   (210, 210)],
#  'Jynx': [(698, 698),
#   (1075, 1084),
#   (333, 325),
#   (171, 179),
#   (411, 411),
#   (387, 387),
#   (250, 250),
#   (228, 220),
#   (879, 896),
#   (278, 278),
#   (579, 587),
#   (205, 205),
#   (214, 214),
#   (326, 330),
#   (348, 348),
#   (400, 400),
#   (650, 668),
#   (279, 280),
#   (586, 586),
#   (456, 456),
#   (250, 250),
#   (300, 275),
#   (800, 800),
#   (165, 173),
#   (592, 580),
#   (193, 193),
#   (386, 386),
#   (173, 173),
#   (279, 282),
#   (246, 246),
#   (353, 356),
#   (720, 757),
#   (536, 536),
#   (804, 804),
#   (238, 238),
#   (260, 260),
#   (590, 600),
#   (984, 980),
#   (286, 300),
#   (281, 300),
#   (300, 299),
#   (421, 421),
#   (350, 351),
#   (474, 474),
#   (1144, 1222),
#   (783, 772),
#   (423, 423),
#   (998, 998),
#   (139, 139)],
#  'Kabuto': [(162, 162),
#   (328, 328),
#   (500, 500),
#   (287, 287),
#   (182, 182),
#   (212, 212),
#   (1080, 1096),
#   (299, 299),
#   (160, 160),
#   (183, 183),
#   (425, 425),
#   (86, 86),
#   (616, 612),
#   (70, 70),
#   (221, 227),
#   (148, 148),
#   (336, 336),
#   (1005, 1005),
#   (929, 940),
#   (881, 888),
#   (215, 215),
#   (262, 262),
#   (304, 304),
#   (200, 200),
#   (1661, 1661),
#   (244, 244),
#   (616, 570),
#   (280, 280),
#   (722, 724),
#   (199, 199),
#   (250, 250),
#   (164, 164),
#   (302, 306),
#   (826, 826),
#   (149, 149),
#   (241, 239),
#   (360, 362),
#   (547, 547),
#   (137, 137),
#   (720, 748),
#   (373, 373),
#   (219, 219),
#   (139, 139),
#   (200, 205),
#   (828, 828),
#   (395, 402),
#   (187, 187),
#   (488, 488),
#   (182, 187)],
#  'Kabutops': [(191, 191),
#   (699, 711),
#   (215, 215),
#   (243, 243),
#   (178, 178),
#   (317, 327),
#   (138, 138),
#   (170, 170),
#   (833, 839),
#   (833, 833),
#   (720, 734),
#   (268, 268),
#   (324, 324),
#   (500, 500),
#   (228, 228),
#   (701, 713),
#   (256, 256),
#   (393, 398),
#   (800, 800),
#   (218, 218),
#   (274, 274),
#   (576, 576),
#   (180, 180),
#   (170, 170),
#   (872, 818),
#   (300, 300),
#   (220, 220),
#   (278, 280),
#   (219, 219),
#   (161, 161),
#   (156, 156),
#   (450, 476),
#   (881, 898),
#   (894, 894),
#   (333, 337),
#   (220, 220),
#   (1151, 1151),
#   (221, 221),
#   (250, 250),
#   (265, 261),
#   (732, 732),
#   (437, 434)],
#  'Kadabra': [(197, 197),
#   (231, 224),
#   (530, 550),
#   (623, 600),
#   (237, 238),
#   (711, 711),
#   (300, 275),
#   (550, 550),
#   (428, 421),
#   (1080, 1086),
#   (235, 235),
#   (593, 593),
#   (293, 295),
#   (341, 341),
#   (716, 715),
#   (512, 512),
#   (196, 196),
#   (408, 410),
#   (376, 381),
#   (148, 148),
#   (164, 164),
#   (881, 915),
#   (288, 300),
#   (250, 250),
#   (720, 749),
#   (477, 477),
#   (149, 145),
#   (250, 250),
#   (637, 661),
#   (349, 349),
#   (478, 479),
#   (709, 716),
#   (628, 650),
#   (422, 422),
#   (186, 186),
#   (224, 228),
#   (500, 500),
#   (250, 250),
#   (768, 767),
#   (360, 371),
#   (88, 88),
#   (459, 452),
#   (377, 375),
#   (281, 267),
#   (161, 161),
#   (172, 158),
#   (184, 184),
#   (251, 242),
#   (940, 940)],
#  'Kakuna': [(192, 192),
#   (250, 250),
#   (1396, 1396),
#   (233, 233),
#   (305, 300),
#   (139, 139),
#   (132, 132),
#   (112, 112),
#   (69, 69),
#   (480, 480),
#   (141, 141),
#   (1492, 1492),
#   (206, 206),
#   (480, 480),
#   (373, 373),
#   (255, 255),
#   (436, 441),
#   (188, 189),
#   (99, 99),
#   (600, 600),
#   (191, 191),
#   (278, 278),
#   (192, 192),
#   (168, 168),
#   (500, 500),
#   (170, 170),
#   (504, 504),
#   (554, 554),
#   (141, 141),
#   (356, 356),
#   (824, 824),
#   (113, 113),
#   (459, 459),
#   (192, 192),
#   (395, 409),
#   (108, 108),
#   (335, 335),
#   (199, 199),
#   (139, 139),
#   (612, 612),
#   (630, 630),
#   (263, 261),
#   (565, 558),
#   (1943, 1920),
#   (197, 197),
#   (140, 140),
#   (163, 163)],
#  'Kangaskhan': [(175, 175),
#   (113, 113),
#   (500, 500),
#   (380, 380),
#   (560, 568),
#   (136, 136),
#   (300, 286),
#   (426, 431),
#   (185, 185),
#   (1543, 1543),
#   (638, 638),
#   (317, 317),
#   (275, 283),
#   (873, 900),
#   (583, 583),
#   (334, 339),
#   (250, 250),
#   (519, 519),
#   (208, 208),
#   (538, 538),
#   (355, 355),
#   (244, 244),
#   (607, 611),
#   (444, 444),
#   (128, 128),
#   (175, 175),
#   (556, 600),
#   (345, 353),
#   (147, 147),
#   (672, 672),
#   (454, 454),
#   (748, 748),
#   (209, 222),
#   (250, 250),
#   (264, 261),
#   (445, 445),
#   (512, 512),
#   (306, 300),
#   (621, 621),
#   (822, 827),
#   (399, 399),
#   (547, 547),
#   (430, 413),
#   (335, 336),
#   (205, 205),
#   (264, 264),
#   (310, 310),
#   (224, 222),
#   (155, 155),
#   (555, 555),
#   (300, 300)],
#  'Kingler': [(872, 877),
#   (300, 309),
#   (210, 210),
#   (171, 171),
#   (257, 257),
#   (751, 751),
#   (108, 108),
#   (577, 589),
#   (172, 173),
#   (278, 278),
#   (295, 295),
#   (138, 138),
#   (475, 475),
#   (225, 226),
#   (676, 676),
#   (611, 611),
#   (178, 183),
#   (1073, 1076),
#   (421, 423),
#   (278, 291),
#   (250, 250),
#   (800, 800),
#   (600, 608),
#   (166, 166),
#   (191, 195),
#   (261, 263),
#   (594, 594),
#   (720, 730),
#   (280, 280),
#   (494, 505),
#   (224, 224),
#   (184, 184),
#   (223, 223),
#   (800, 800),
#   (137, 137),
#   (621, 621),
#   (600, 600),
#   (709, 709),
#   (480, 485),
#   (350, 350),
#   (624, 650),
#   (280, 284),
#   (1071, 1074),
#   (696, 718),
#   (315, 318),
#   (309, 309),
#   (224, 224)],
#  'Koffing': [(120, 120),
#   (321, 320),
#   (295, 300),
#   (174, 174),
#   (256, 256),
#   (252, 252),
#   (1500, 1500),
#   (473, 473),
#   (683, 683),
#   (353, 400),
#   (144, 144),
#   (720, 731),
#   (185, 185),
#   (232, 232),
#   (197, 197),
#   (499, 499),
#   (586, 586),
#   (1000, 1000),
#   (180, 200),
#   (260, 269),
#   (600, 600),
#   (934, 934),
#   (142, 142),
#   (328, 328),
#   (315, 315),
#   (843, 845),
#   (845, 845),
#   (850, 900),
#   (242, 242),
#   (208, 208),
#   (870, 873),
#   (236, 236),
#   (678, 678),
#   (799, 799),
#   (771, 771),
#   (259, 259),
#   (144, 144),
#   (2869, 2857),
#   (230, 230),
#   (112, 113),
#   (499, 499),
#   (111, 111),
#   (500, 500),
#   (250, 250),
#   (189, 189),
#   (100, 103),
#   (218, 218),
#   (157, 157)],
#  'Krabby': [(614, 614),
#   (319, 317),
#   (280, 280),
#   (313, 313),
#   (296, 296),
#   (718, 722),
#   (250, 250),
#   (208, 208),
#   (301, 301),
#   (457, 472),
#   (850, 884),
#   (281, 281),
#   (139, 147),
#   (677, 677),
#   (238, 243),
#   (1248, 1248),
#   (209, 213),
#   (662, 662),
#   (394, 394),
#   (429, 429),
#   (147, 147),
#   (180, 180),
#   (355, 355),
#   (150, 155),
#   (138, 138),
#   (312, 313),
#   (144, 144),
#   (240, 246),
#   (712, 731),
#   (166, 166),
#   (600, 600),
#   (137, 137),
#   (132, 135),
#   (1758, 1758),
#   (432, 432),
#   (300, 300),
#   (256, 256),
#   (150, 152),
#   (303, 303),
#   (1063, 1079),
#   (156, 156),
#   (69, 69),
#   (151, 154),
#   (796, 801),
#   (200, 200),
#   (270, 270),
#   (259, 259),
#   (173, 173)],
#  'Lapras': [(1500, 1500),
#   (851, 865),
#   (632, 632),
#   (240, 244),
#   (454, 460),
#   (149, 154),
#   (874, 862),
#   (2381, 2381),
#   (290, 290),
#   (467, 467),
#   (167, 167),
#   (145, 145),
#   (236, 236),
#   (500, 500),
#   (879, 881),
#   (249, 249),
#   (684, 690),
#   (270, 273),
#   (296, 300),
#   (1500, 1500),
#   (543, 543),
#   (1500, 1500),
#   (754, 754),
#   (835, 759),
#   (122, 122),
#   (630, 596),
#   (999, 1003),
#   (326, 350),
#   (207, 207),
#   (122, 124),
#   (218, 218),
#   (242, 237),
#   (600, 604),
#   (519, 520),
#   (304, 304),
#   (300, 275),
#   (349, 355),
#   (507, 520),
#   (666, 666),
#   (134, 134),
#   (601, 592),
#   (256, 256),
#   (1200, 1200),
#   (689, 689),
#   (300, 300),
#   (300, 300),
#   (250, 250),
#   (507, 504),
#   (184, 184),
#   (443, 443),
#   (1024, 1024),
#   (560, 560),
#   (553, 555)],
#  'Lickitung': [(184, 184),
#   (809, 805),
#   (176, 176),
#   (92, 98),
#   (772, 782),
#   (157, 154),
#   (776, 834),
#   (800, 800),
#   (220, 220),
#   (235, 235),
#   (845, 839),
#   (336, 336),
#   (279, 300),
#   (389, 388),
#   (871, 871),
#   (600, 600),
#   (181, 181),
#   (570, 561),
#   (323, 323),
#   (182, 182),
#   (250, 250),
#   (250, 250),
#   (616, 616),
#   (178, 178),
#   (618, 613),
#   (250, 250),
#   (324, 324),
#   (208, 208),
#   (175, 175),
#   (315, 315),
#   (406, 418),
#   (421, 395),
#   (256, 256),
#   (226, 226),
#   (394, 404),
#   (474, 474),
#   (143, 143),
#   (800, 800),
#   (903, 903),
#   (300, 300),
#   (296, 296),
#   (300, 269),
#   (200, 200),
#   (164, 164),
#   (519, 519),
#   (432, 443),
#   (800, 800),
#   (550, 550)],
#  'Machamp': [(288, 288),
#   (232, 232),
#   (142, 142),
#   (237, 237),
#   (519, 521),
#   (80, 80),
#   (320, 308),
#   (322, 318),
#   (516, 517),
#   (283, 283),
#   (280, 280),
#   (250, 250),
#   (333, 333),
#   (694, 694),
#   (256, 256),
#   (349, 349),
#   (405, 405),
#   (355, 355),
#   (291, 291),
#   (141, 144),
#   (329, 323),
#   (152, 150),
#   (227, 220),
#   (803, 803),
#   (689, 686),
#   (948, 954),
#   (1045, 1024),
#   (881, 892),
#   (160, 157),
#   (550, 549),
#   (264, 264),
#   (423, 422),
#   (136, 136),
#   (127, 127),
#   (615, 599),
#   (571, 571),
#   (245, 244),
#   (304, 304),
#   (877, 885),
#   (150, 150),
#   (708, 700),
#   (315, 315),
#   (250, 250),
#   (562, 562),
#   (301, 300),
#   (206, 206),
#   (193, 193),
#   (405, 405),
#   (122, 122),
#   (1535, 1533),
#   (575, 575),
#   (227, 224),
#   (800, 800)],
#  'Machoke': [(500, 500),
#   (250, 250),
#   (871, 875),
#   (881, 883),
#   (484, 484),
#   (300, 300),
#   (143, 143),
#   (250, 250),
#   (1045, 1024),
#   (141, 140),
#   (189, 189),
#   (383, 383),
#   (278, 278),
#   (334, 334),
#   (182, 182),
#   (572, 558),
#   (300, 282),
#   (477, 480),
#   (223, 223),
#   (600, 619),
#   (603, 603),
#   (113, 113),
#   (715, 717),
#   (217, 217),
#   (280, 275),
#   (203, 201),
#   (857, 845),
#   (1177, 1168),
#   (330, 332),
#   (368, 368),
#   (1040, 1024),
#   (800, 800),
#   (524, 500),
#   (227, 226),
#   (220, 220),
#   (436, 438),
#   (198, 198),
#   (128, 128),
#   (816, 834),
#   (185, 181),
#   (618, 602),
#   (148, 148)],
#  'Machop': [(720, 726),
#   (143, 143),
#   (298, 298),
#   (865, 866),
#   (247, 246),
#   (135, 135),
#   (465, 465),
#   (400, 400),
#   (133, 133),
#   (485, 485),
#   (194, 193),
#   (128, 128),
#   (1101, 1101),
#   (800, 800),
#   (500, 500),
#   (639, 638),
#   (959, 959),
#   (250, 250),
#   (253, 253),
#   (148, 148),
#   (589, 589),
#   (603, 597),
#   (201, 201),
#   (484, 484),
#   (351, 352),
#   (488, 488),
#   (93, 93),
#   (1080, 1080),
#   (283, 278),
#   (400, 400),
#   (315, 315),
#   (110, 110),
#   (209, 209),
#   (252, 252),
#   (495, 490),
#   (500, 500),
#   (496, 496),
#   (207, 207),
#   (296, 268),
#   (191, 191),
#   (541, 541)],
#  'Magikarp': [(745, 745),
#   (377, 377),
#   (180, 187),
#   (67, 67),
#   (141, 141),
#   (517, 517),
#   (160, 160),
#   (691, 686),
#   (188, 188),
#   (174, 180),
#   (300, 300),
#   (424, 424),
#   (1200, 1200),
#   (723, 723),
#   (157, 157),
#   (169, 169),
#   (308, 313),
#   (627, 627),
#   (168, 168),
#   (923, 943),
#   (957, 911),
#   (269, 262),
#   (338, 300),
#   (640, 626),
#   (591, 591),
#   (406, 411),
#   (300, 300),
#   (189, 190),
#   (310, 310),
#   (280, 280),
#   (586, 588),
#   (802, 809),
#   (352, 352),
#   (250, 250),
#   (475, 478),
#   (203, 203),
#   (322, 322),
#   (388, 388),
#   (317, 317),
#   (214, 216),
#   (139, 139),
#   (425, 425),
#   (488, 490),
#   (355, 355)],
#  'Magmar': [(186, 180),
#   (264, 264),
#   (181, 181),
#   (780, 780),
#   (197, 197),
#   (315, 312),
#   (663, 667),
#   (76, 76),
#   (326, 328),
#   (502, 502),
#   (268, 268),
#   (275, 278),
#   (149, 149),
#   (495, 495),
#   (280, 280),
#   (250, 250),
#   (647, 657),
#   (647, 644),
#   (576, 576),
#   (185, 185),
#   (707, 722),
#   (446, 446),
#   (764, 764),
#   (703, 699),
#   (373, 373),
#   (293, 300),
#   (698, 698),
#   (134, 134),
#   (425, 425),
#   (558, 556),
#   (877, 881),
#   (190, 190),
#   (217, 217),
#   (800, 800),
#   (782, 782),
#   (1039, 1013),
#   (320, 348),
#   (448, 438),
#   (140, 140),
#   (96, 96),
#   (536, 536),
#   (332, 332),
#   (339, 339),
#   (176, 176)],
#  'Magnemite': [(187, 189),
#   (212, 212),
#   (247, 249),
#   (206, 206),
#   (380, 383),
#   (1080, 1098),
#   (600, 600),
#   (104, 103),
#   (720, 747),
#   (1233, 1233),
#   (252, 255),
#   (383, 383),
#   (423, 423),
#   (159, 159),
#   (805, 815),
#   (555, 565),
#   (878, 882),
#   (256, 256),
#   (250, 250),
#   (211, 211),
#   (434, 440),
#   (209, 209),
#   (353, 360),
#   (881, 888),
#   (684, 701),
#   (1080, 1080),
#   (717, 720),
#   (1500, 1500),
#   (461, 461),
# ...
#   (1024, 1018),
#   (833, 805),
#   (939, 900),
#   (1505, 1422),
#   (842, 813),
#   (554, 549),
#   (848, 848),
#   (806, 770),
#   (815, 822),
#   (673, 673),
#   (688, 688),
#   (738, 734),
#   (871, 918),
#   (1024, 1024),
#   (794, 793),
#   (903, 898),
#   (894, 891),
#   (506, 487),
#   (849, 874),
#   (800, 781),
#   (918, 918),
#   (854, 863),
#   (887, 884),
#   (1000, 1000),
#   (1035, 1035),
#   (644, 643),
#   (678, 681),
#   (1515, 1515),
#   (800, 792),
#   (491, 491),
#   (688, 688),
#   (690, 691),
#   (453, 453),
#   (800, 800),
#   (887, 779),
#   (812, 812),
#   (640, 640),
#   (800, 800),
#   (1025, 779),
#   (979, 816),
#   (700, 1400),
#   (870, 900),
#   (640, 640),
#   (669, 670),
#   (167, 167),
#   (1114, 1078),
#   (647, 639),
#   (777, 758),
#   (137, 140),
#   (775, 775)],
#  'Starmie': [(115, 108),
#   (343, 340),
#   (736, 736),
#   (520, 536),
#   (280, 280),
#   (322, 335),
#   (330, 355),
#   (881, 1030),
#   (500, 500),
#   (170, 165),
#   (62, 63),
#   (256, 256),
#   (250, 250),
#   (1920, 1920),
#   (294, 257),
#   (963, 1129),
#   (141, 160),
#   (310, 310),
#   (555, 643),
#   (955, 978),
#   (593, 577),
#   (361, 333),
#   (171, 169),
#   (195, 225),
#   (133, 129),
#   (667, 650),
#   (154, 157),
#   (904, 866),
#   (800, 800),
#   (810, 844),
#   (510, 555),
#   (456, 462),
#   (286, 277),
#   (630, 630),
#   (284, 320),
#   (380, 436),
#   (342, 320),
#   (882, 900),
#   (300, 292),
#   (881, 1174),
#   (611, 645),
#   (124, 117),
#   (595, 600),
#   (575, 548),
#   (426, 503),
#   (294, 330),
#   (346, 344),
#   (256, 300),
#   (147, 141)],
#  'Staryu': [(372, 368),
#   (145, 145),
#   (300, 279),
#   (881, 943),
#   (401, 402),
#   (405, 378),
#   (145, 130),
#   (800, 800),
#   (296, 289),
#   (250, 250),
#   (377, 380),
#   (293, 286),
#   (241, 208),
#   (875, 913),
#   (47, 48),
#   (410, 398),
#   (448, 441),
#   (601, 612),
#   (195, 181),
#   (350, 350),
#   (881, 993),
#   (205, 197),
#   (187, 193),
#   (167, 162),
#   (347, 348),
#   (896, 896),
#   (200, 200),
#   (286, 300),
#   (141, 160),
#   (93, 93),
#   (359, 333),
#   (95, 99),
#   (194, 201),
#   (606, 570),
#   (260, 260),
#   (135, 134),
#   (325, 349),
#   (150, 141),
#   (117, 114),
#   (1080, 1124),
#   (240, 210),
#   (302, 289),
#   (512, 529),
#   (256, 256),
#   (242, 225),
#   (456, 467),
#   (685, 690)],
#  'Tangela': [(151, 158),
#   (250, 250),
#   (764, 900),
#   (89, 85),
#   (256, 256),
#   (230, 210),
#   (861, 900),
#   (761, 791),
#   (169, 151),
#   (175, 175),
#   (246, 249),
#   (196, 185),
#   (160, 159),
#   (1200, 1200),
#   (199, 199),
#   (230, 210),
#   (525, 506),
#   (300, 300),
#   (348, 360),
#   (150, 162),
#   (345, 322),
#   (573, 584),
#   (549, 515),
#   (68, 66),
#   (238, 233),
#   (200, 174),
#   (125, 124),
#   (1000, 1028),
#   (273, 300),
#   (174, 154),
#   (183, 183),
#   (207, 198),
#   (214, 206),
#   (367, 386),
#   (182, 194),
#   (731, 755),
#   (458, 469),
#   (791, 840),
#   (146, 156),
#   (881, 967),
#   (316, 301),
#   (372, 355),
#   (260, 239),
#   (226, 208),
#   (314, 321),
#   (172, 172),
#   (145, 139),
#   (126, 118),
#   (1200, 1200),
#   (232, 237),
#   (657, 765),
#   (369, 361),
#   (463, 462)],
#  'Tauros': [(396, 425),
#   (298, 277),
#   (147, 148),
#   (249, 245),
#   (76, 73),
#   (600, 600),
#   (536, 542),
#   (749, 736),
#   (881, 912),
#   (684, 658),
#   (103, 102),
#   (800, 800),
#   (284, 277),
#   (720, 682),
#   (134, 126),
#   (629, 691),
#   (300, 322),
#   (196, 205),
#   (268, 300),
#   (240, 224),
#   (702, 613),
#   (517, 528),
#   (406, 384),
#   (153, 148),
#   (826, 844),
#   (422, 403),
#   (207, 202),
#   (658, 672),
#   (300, 257),
#   (196, 187),
#   (776, 773),
#   (460, 447),
#   (369, 359),
#   (638, 708),
#   (198, 202),
#   (212, 213),
#   (829, 813),
#   (443, 435),
#   (439, 540),
#   (643, 651),
#   (525, 579),
#   (256, 256),
#   (215, 215),
#   (881, 827),
#   (382, 394),
#   (128, 124),
#   (209, 228),
#   (198, 199),
#   (615, 674),
#   (250, 250),
#   (560, 525),
#   (640, 670),
#   (224, 228),
#   (434, 471)],
#  'Tentacool': [(1031, 1024),
#   (89, 86),
#   (173, 170),
#   (657, 657),
#   (448, 436),
#   (445, 445),
#   (204, 215),
#   (247, 255),
#   (1200, 1164),
#   (189, 175),
#   (75, 77),
#   (140, 137),
#   (250, 259),
#   (622, 568),
#   (250, 250),
#   (256, 256),
#   (185, 174),
#   (280, 327),
#   (438, 405),
#   (476, 486),
#   (127, 127),
#   (289, 286),
#   (166, 160),
#   (627, 595),
#   (444, 445),
#   (180, 184),
#   (220, 213),
#   (165, 185),
#   (174, 175),
#   (215, 200),
#   (518, 507),
#   (429, 410),
#   (557, 550),
#   (736, 736),
#   (108, 115),
#   (277, 264),
#   (118, 120),
#   (144, 154),
#   (606, 600),
#   (322, 300),
#   (273, 252),
#   (351, 345),
#   (200, 200),
#   (758, 800),
#   (600, 600)],
#  'Tentacruel': [(113, 120),
#   (267, 277),
#   (128, 130),
#   (187, 187),
#   (216, 205),
#   (186, 186),
#   (326, 329),
#   (747, 764),
#   (135, 146),
#   (216, 214),
#   (1200, 1200),
#   (250, 250),
#   (185, 170),
#   (233, 239),
#   (397, 397),
#   (774, 793),
#   (1200, 1188),
#   (182, 191),
#   (294, 295),
#   (185, 174),
#   (694, 699),
#   (132, 145),
#   (123, 125),
#   (332, 343),
#   (838, 846),
#   (237, 219),
#   (170, 191),
#   (419, 419),
#   (720, 706),
#   (381, 381),
#   (312, 321),
#   (302, 299),
#   (189, 198),
#   (347, 354),
#   (702, 707),
#   (153, 150),
#   (541, 551),
#   (384, 320),
#   (197, 196),
#   (386, 386),
#   (720, 762),
#   (256, 256),
#   (121, 135),
#   (881, 942),
#   (776, 778),
#   (140, 145),
#   (368, 373)],
#  'Vaporeon': [(143, 141),
#   (327, 323),
#   (576, 522),
#   (139, 147),
#   (776, 738),
#   (280, 289),
#   (222, 222),
#   (211, 203),
#   (155, 145),
#   (780, 785),
#   (720, 683),
#   (800, 800),
#   (458, 458),
#   (456, 460),
#   (170, 176),
#   (274, 235),
#   (450, 468),
#   (305, 297),
#   (500, 500),
#   (291, 300),
#   (250, 250),
#   (449, 393),
#   (322, 333),
#   (597, 592),
#   (1101, 1015),
#   (379, 318),
#   (141, 148),
#   (255, 271),
#   (1149, 1024),
#   (199, 186),
#   (720, 758),
#   (419, 444),
#   (485, 500),
#   (367, 346),
#   (624, 638),
#   (1099, 1073),
#   (600, 600),
#   (796, 761),
#   (881, 914),
#   (921, 800),
#   (688, 700),
#   (1500, 1500),
#   (368, 370),
#   (500, 461),
#   (881, 961),
#   (1500, 1500),
#   (278, 226),
#   (470, 505),
#   (899, 779),
#   (869, 812),
#   (766, 769),
#   (123, 141),
#   (630, 630),
#   (178, 171),
#   (1024, 1024),
#   (384, 399),
#   (247, 239),
#   (782, 743),
#   (240, 210)],
#  'Venomoth': [(360, 350),
#   (551, 564),
#   (270, 282),
#   (250, 250),
#   (187, 204),
#   (1630, 1729),
#   (368, 394),
#   (367, 418),
#   (881, 910),
#   (221, 234),
#   (850, 814),
#   (1148, 1229),
#   (881, 899),
#   (812, 812),
#   (1268, 1413),
#   (217, 208),
#   (178, 173),
#   (187, 189),
#   (534, 530),
#   (267, 300),
#   (267, 267),
#   (150, 158),
#   (637, 642),
#   (173, 173),
#   (197, 196),
#   (382, 396),
#   (1268, 1413),
#   (260, 263),
#   (305, 334),
#   (182, 181),
#   (120, 120),
#   (155, 153),
#   (188, 233),
#   (600, 600),
#   (297, 326),
#   (539, 585),
#   (179, 184),
#   (225, 219),
#   (894, 894),
#   (720, 755),
#   (386, 418),
#   (226, 226),
#   (264, 276),
#   (218, 233),
#   (227, 214),
#   (660, 698),
#   (169, 189),
#   (650, 651),
#   (160, 152),
#   (800, 800),
#   (507, 591),
#   (199, 188)],
#  'Venonat': [(456, 400),
#   (900, 876),
#   (171, 164),
#   (394, 403),
#   (240, 210),
#   (254, 245),
#   (697, 659),
#   (640, 500),
#   (303, 303),
#   (250, 250),
#   (599, 504),
#   (146, 138),
#   (800, 800),
#   (156, 155),
#   (437, 428),
#   (317, 306),
#   (433, 419),
#   (720, 726),
#   (1155, 1061),
#   (935, 921),
#   (484, 461),
#   (401, 414),
#   (108, 112),
#   (151, 145),
#   (267, 267),
#   (674, 638),
#   (117, 107),
#   (706, 737),
#   (236, 214),
#   (142, 139),
#   (436, 433),
#   (245, 215),
#   (318, 308),
#   (240, 210),
#   (461, 438),
#   (306, 290),
#   (881, 945),
#   (352, 357),
#   (600, 600),
#   (704, 800),
#   (600, 586),
#   (546, 540),
#   (150, 149),
#   (300, 303),
#   (300, 268),
#   (402, 384),
#   (347, 343)],
#  'Venusaur': [(720, 1280),
#   (280, 280),
#   (1253, 2158),
#   (256, 256),
#   (703, 1024),
#   (881, 1174),
#   (617, 800),
#   (215, 300),
#   (739, 1080),
#   (187, 220),
#   (881, 1174),
#   (266, 300),
#   (617, 611),
#   (600, 600),
#   (1080, 1920),
#   (461, 628),
#   (420, 420),
#   (250, 250),
#   (342, 246),
#   (256, 256),
#   (440, 336),
#   (1500, 1500),
#   (1100, 986),
#   (691, 750),
#   (218, 300),
#   (532, 900),
#   (250, 250),
#   (720, 1280),
#   (345, 466),
#   (1497, 1436),
#   (757, 1024),
#   (450, 323),
#   (165, 220),
#   (202, 228),
#   (386, 480),
#   (881, 1566),
#   (576, 1024),
#   (480, 480),
#   (368, 654),
#   (720, 1280),
#   (360, 360),
#   (217, 300),
#   (536, 500),
#   (342, 245),
#   (240, 420),
#   (248, 290),
#   (263, 350),
#   (720, 1280),
#   (1038, 747),
#   (450, 321),
#   (720, 1280),
#   (349, 620),
#   (790, 570),
#   (853, 1281),
#   (720, 1280),
#   (512, 512),
#   (1200, 1920),
#   (731, 800),
#   (450, 320),
#   (881, 1174),
#   (566, 800),
#   (920, 736),
#   (1200, 1920),
#   (176, 232),
#   (342, 245),
#   (377, 500)],
#  'Victreebel': [(512, 593),
#   (1049, 1049),
#   (731, 792),
#   (583, 564),
#   (307, 287),
#   (1172, 1355),
#   (538, 538),
#   (288, 317),
#   (217, 218),
#   (904, 866),
#   (645, 625),
#   (208, 213),
#   (256, 256),
#   (881, 907),
#   (508, 531),
#   (623, 612),
#   (894, 894),
#   (296, 300),
#   (135, 142),
#   (371, 371),
#   (446, 446),
#   (644, 720),
#   (728, 720),
#   (266, 262),
#   (501, 485),
#   (212, 214),
#   (478, 445),
#   (303, 300),
#   (250, 250),
#   (176, 182),
#   (280, 280),
#   (92, 92),
#   (320, 305),
#   (142, 142),
#   (881, 937),
#   (347, 384),
#   (408, 456),
#   (156, 163),
#   (616, 600),
#   (740, 752),
#   (432, 432),
#   (164, 159),
#   (360, 369),
#   (233, 233),
#   (235, 235),
#   (268, 300),
#   (240, 210),
#   (186, 217),
#   (881, 1012)],
#  'Vileplume': [(1239, 1348),
#   (650, 650),
#   (452, 533),
#   (173, 169),
#   (425, 431),
#   (164, 158),
#   (154, 144),
#   (764, 878),
#   (215, 215),
#   (233, 251),
#   (143, 137),
#   (207, 218),
#   (295, 314),
#   (770, 805),
#   (212, 211),
#   (528, 593),
#   (937, 1391),
#   (828, 811),
#   (198, 199),
#   (172, 172),
#   (277, 277),
#   (200, 223),
#   (475, 486),
#   (285, 300),
#   (243, 255),
#   (250, 300),
#   (148, 148),
#   (250, 250),
#   (464, 462),
#   (195, 209),
#   (600, 584),
#   (396, 386),
#   (783, 899),
#   (282, 300),
#   (368, 400),
#   (335, 307),
#   (631, 635),
#   (392, 403),
#   (126, 115),
#   (764, 713),
#   (773, 843),
#   (208, 203),
#   (319, 276),
#   (120, 120),
#   (251, 263),
#   (154, 133),
#   (358, 328),
#   (384, 381),
#   (480, 501),
#   (202, 210),
#   (176, 186),
#   (720, 712),
#   (720, 743),
#   (256, 256),
#   (714, 684),
#   (152, 160)],
#  'Voltorb': [(408, 363),
#   (145, 143),
#   (892, 892),
#   (235, 235),
#   (757, 726),
#   (140, 146),
#   (159, 150),
#   (114, 100),
#   (199, 185),
#   (768, 779),
#   (500, 513),
#   (336, 330),
#   (795, 814),
#   (266, 261),
#   (300, 300),
#   (432, 388),
#   (278, 278),
#   (250, 250),
#   (480, 480),
#   (72, 60),
#   (130, 124),
#   (153, 144),
#   (261, 251),
#   (201, 205),
#   (140, 136),
#   (256, 256),
#   (453, 412),
#   (800, 800),
#   (372, 351),
#   (142, 135),
#   (361, 367),
#   (171, 166),
#   (350, 310),
#   (426, 401),
#   (133, 126),
#   (338, 318),
#   (212, 210),
#   (800, 1200),
#   (642, 635),
#   (67, 65),
#   (320, 320),
#   (500, 500),
#   (267, 267),
#   (550, 572),
#   (307, 318),
#   (932, 899),
#   (155, 160),
#   (358, 320),
#   (1688, 1636),
#   (576, 601),
#   (812, 858),
#   (620, 538),
#   (151, 137),
#   (230, 230),
#   (298, 300)],
#  'Vulpix': [(256, 256),
#   (261, 232),
#   (291, 300),
#   (881, 887),
#   (179, 179),
#   (720, 778),
#   (280, 300),
#   (639, 575),
#   (320, 302),
#   (220, 240),
#   (1512, 1423),
#   (1200, 1217),
#   (383, 400),
#   (800, 836),
#   (415, 415),
#   (214, 208),
#   (254, 263),
#   (1500, 1500),
#   (308, 302),
#   (115, 108),
#   (621, 683),
#   (592, 566),
#   (309, 311),
#   (311, 300),
#   (974, 872),
#   (845, 830),
#   (368, 361),
#   (566, 591),
#   (720, 711),
#   (630, 630),
#   (237, 243),
#   (237, 237),
#   (252, 236),
#   (659, 699),
#   (316, 354),
#   (271, 300),
#   (240, 210),
#   (153, 134),
#   (600, 600),
#   (600, 600),
#   (881, 864),
#   (160, 150),
#   (407, 473),
#   (494, 400),
#   (146, 148),
#   (770, 797),
#   (1644, 1666),
#   (250, 250),
#   (480, 538),
#   (1513, 1513)],
#  'Wartortle': [(140, 116),
#   (400, 400),
#   (383, 376),
#   (800, 800),
#   (138, 138),
#   (300, 300),
#   (720, 680),
#   (929, 860),
#   (455, 471),
#   (446, 446),
#   (131, 131),
#   (946, 946),
#   (666, 658),
#   (435, 435),
#   (300, 290),
#   (300, 294),
#   (185, 194),
#   (139, 139),
#   (113, 114),
#   (376, 350),
#   (174, 163),
#   (240, 210),
#   (181, 183),
#   (1118, 1024),
#   (881, 932),
#   (237, 226),
#   (498, 471),
#   (1669, 1669),
#   (185, 186),
#   (402, 385),
#   (148, 125),
#   (600, 610),
#   (891, 861),
#   (827, 827),
#   (601, 640),
#   (1249, 1205),
#   (706, 660),
#   (269, 249),
#   (500, 500),
#   (467, 453),
#   (776, 747),
#   (173, 168),
#   (223, 219),
#   (165, 159),
#   (240, 242),
#   (250, 250),
#   (498, 472),
#   (255, 243)],
#  'Weedle': [(156, 149),
#   (152, 141),
#   (233, 217),
#   (697, 594),
#   (96, 96),
#   (143, 149),
#   (157, 157),
#   (502, 482),
#   (81, 79),
#   (300, 281),
#   (479, 476),
#   (427, 398),
#   (439, 420),
#   (720, 731),
#   (600, 600),
#   (800, 800),
#   (928, 823),
#   (800, 800),
#   (606, 586),
#   (304, 292),
#   (305, 355),
#   (393, 409),
#   (990, 1021),
#   (147, 147),
#   (550, 505),
#   (405, 405),
#   (1648, 1514),
#   (185, 181),
#   (79, 79),
#   (539, 520),
#   (390, 365),
#   (108, 108),
#   (203, 209),
#   (70, 70),
#   (212, 194),
#   (826, 757),
#   (250, 250),
#   (68, 70),
#   (155, 162),
#   (792, 736),
#   (598, 526),
#   (226, 226),
#   (405, 438),
#   (762, 669),
#   (152, 143),
#   (215, 223),
#   (160, 166),
#   (591, 574),
#   (93, 94)],
#  'Weepinbell': [(141, 150),
#   (720, 780),
#   (360, 357),
#   (434, 444),
#   (280, 280),
#   (139, 148),
#   (256, 256),
#   (600, 550),
#   (240, 240),
#   (165, 165),
#   (401, 427),
#   (164, 162),
#   (143, 148),
#   (848, 990),
#   (256, 260),
#   (174, 165),
#   (289, 283),
#   (975, 981),
#   (396, 419),
#   (76, 76),
#   (570, 581),
#   (497, 497),
#   (213, 249),
#   (635, 635),
#   (228, 250),
#   (384, 384),
#   (134, 127),
#   (670, 722),
#   (541, 558),
#   (716, 726),
#   (352, 320),
#   (286, 253),
#   (116, 111),
#   (881, 961),
#   (186, 176),
#   (840, 887),
#   (701, 685),
#   (250, 250),
#   (500, 500),
#   (444, 451),
#   (337, 334),
#   (441, 500),
#   (160, 161)],
#  'Weezing': [(270, 295),
#   (256, 297),
#   (256, 256),
#   (744, 744),
#   (229, 240),
#   (850, 879),
#   (186, 181),
#   (168, 154),
#   (576, 612),
#   (782, 854),
#   (159, 148),
#   (789, 916),
#   (257, 283),
#   (143, 148),
#   (250, 252),
#   (488, 503),
#   (126, 137),
#   (149, 137),
#   (538, 538),
#   (175, 170),
#   (265, 265),
#   (742, 742),
#   (800, 800),
#   (463, 479),
#   (719, 719),
#   (881, 984),
#   (141, 123),
#   (258, 300),
#   (212, 198),
#   (250, 250),
#   (439, 443),
#   (392, 392),
#   (300, 323),
#   (250, 250),
#   (140, 147),
#   (293, 300),
#   (360, 413),
#   (650, 650),
#   (151, 216),
#   (119, 121),
#   (1064, 1413),
#   (844, 849),
#   (235, 235),
#   (197, 197),
#   (720, 776),
#   (634, 626),
#   (150, 148),
#   (216, 235),
#   (256, 256),
#   (214, 214)],
#  'Wigglytuff': [(690, 690),
#   (297, 291),
#   (134, 139),
#   (101, 110),
#   (1387, 1387),
#   (121, 121),
#   (129, 131),
#   (639, 597),
#   (436, 408),
#   (207, 200),
#   (513, 508),
#   (167, 167),
#   (169, 169),
#   (150, 150),
#   (124, 126),
#   (312, 312),
#   (148, 148),
#   (200, 200),
#   (379, 377),
#   (282, 282),
#   (941, 1009),
#   (117, 118),
#   (703, 634),
#   (597, 584),
#   (138, 140),
#   (881, 939),
#   (455, 429),
#   (163, 159),
#   (128, 128),
#   (555, 533),
#   (533, 503),
#   (851, 809),
#   (839, 844),
#   (162, 152),
#   (228, 210),
#   (250, 250),
#   (1001, 987),
#   (523, 532),
#   (677, 625),
#   (252, 275),
#   (68, 64),
#   (294, 280),
#   (268, 244),
#   (556, 554),
#   (453, 428),
#   (183, 176),
#   (120, 121),
#   (300, 300),
#   (134, 144),
#   (338, 314),
#   (164, 172),
#   (240, 210),
#   (481, 479),
#   (107, 97),
#   (508, 428),
#   (1019, 1000),
#   (238, 226)],
#  'Zapdos': [(84, 84),
#   (360, 387),
#   (674, 701),
#   (101, 98),
#   (375, 375),
#   (374, 376),
#   (1200, 1200),
#   (170, 170),
#   (204, 202),
#   (458, 484),
#   (229, 236),
#   (548, 548),
#   (192, 192),
#   (641, 597),
#   (143, 143),
#   (450, 483),
#   (489, 524),
#   (658, 658),
#   (720, 711),
#   (428, 458),
#   (514, 546),
#   (207, 212),
#   (195, 205),
#   (314, 314),
#   (490, 515),
#   (350, 372),
#   (825, 825),
#   (886, 886),
#   (285, 300),
#   (343, 343),
#   (881, 882),
#   (356, 353),
#   (458, 458),
#   (460, 412),
#   (500, 500),
#   (866, 994),
#   (218, 204),
#   (367, 367),
#   (157, 156),
#   (632, 635),
#   (320, 325),
#   (1352, 1370),
#   (475, 475),
#   (296, 296),
#   (250, 250),
#   (351, 359),
#   (325, 338),
#   (259, 300),
#   (731, 749),
#   (522, 522),
#   (393, 384)],
#  'Zubat': [(160, 160),
#   (370, 370),
#   (343, 343),
#   (128, 128),
#   (95, 95),
#   (198, 198),
#   (549, 549),
#   (600, 626),
#   (346, 371),
#   (180, 180),
#   (1140, 1140),
#   (793, 800),
#   (1920, 1920),
#   (250, 250),
#   (558, 558),
#   (900, 900),
#   (487, 487),
#   (188, 188),
#   (256, 256),
#   (502, 562),
#   (354, 354),
#   (135, 135),
#   (420, 420),
#   (447, 447),
#   (800, 800),
#   (720, 764),
#   (395, 395),
#   (122, 122),
#   (121, 121),
#   (762, 763),
#   (574, 581),
#   (323, 320),
#   (591, 593),
#   (558, 554),
#   (172, 172),
#   (324, 327),
#   (222, 207),
#   (500, 500),
#   (342, 342),
#   (136, 136)]}

# %%
stastics_arr = []
for key in classes_img_stat:
    buff_arr = np.array(classes_img_stat[key])
    stats ={
        'cls_mean' : buff_arr.mean(axis=0),
        'cls_max'  : buff_arr.max(axis=0),
        'cls_min'  : buff_arr.min(axis=0),
    }
    stastics_arr.append([
        buff_arr.mean(axis=0),
        buff_arr.max(axis=0),
        buff_arr.min(axis=0)
        ])
    print(key)
    print(stats)
# Out:
# Abra
# {'cls_mean': array([479.57142857, 482.62857143]), 'cls_max': array([2000, 2000]), 'cls_min': array([67, 67])}
# Aerodactyl
# {'cls_mean': array([363.34285714, 364.62857143]), 'cls_max': array([1033, 1065]), 'cls_min': array([116, 116])}
# Alakazam
# {'cls_mean': array([462.38461538, 462.11538462]), 'cls_max': array([1271, 1233]), 'cls_min': array([124, 144])}
# Alolan Sandslash
# {'cls_mean': array([375.36585366, 392.2195122 ]), 'cls_max': array([1149, 1280]), 'cls_min': array([119, 122])}
# Arbok
# {'cls_mean': array([482.07317073, 479.73170732]), 'cls_max': array([2000, 2000]), 'cls_min': array([120, 122])}
# Arcanine
# {'cls_mean': array([579.12195122, 580.26829268]), 'cls_max': array([2570, 2570]), 'cls_min': array([120, 120])}
# Articuno
# {'cls_mean': array([538.2       , 536.97777778]), 'cls_max': array([1254, 1254]), 'cls_min': array([191, 192])}
# Beedrill
# {'cls_mean': array([417.61764706, 413.97058824]), 'cls_max': array([879, 889]), 'cls_min': array([152, 152])}
# Bellsprout
# {'cls_mean': array([468.   , 462.675]), 'cls_max': array([1428, 1425]), 'cls_min': array([61, 61])}
# Blastoise
# {'cls_mean': array([626.61904762, 623.80952381]), 'cls_max': array([2008, 2006]), 'cls_min': array([119, 120])}
# Bulbasaur
# {'cls_mean': array([872.14634146, 907.36585366]), 'cls_max': array([4356, 5000]), 'cls_min': array([141, 153])}
# Butterfree
# {'cls_mean': array([582.51851852, 630.33333333]), 'cls_max': array([1324, 1420]), 'cls_min': array([148, 167])}
# Caterpie
# {'cls_mean': array([482.45945946, 474.16216216]), 'cls_max': array([2592, 1728]), 'cls_min': array([77, 76])}
# Chansey
# {'cls_mean': array([415.58139535, 427.        ]), 'cls_max': array([1500, 1500]), 'cls_min': array([58, 58])}
# Charizard
# {'cls_mean': array([711.31428571, 719.31428571]), 'cls_max': array([1869, 1869]), 'cls_min': array([198, 199])}
# Charmander
# {'cls_mean': array([763.        , 737.66666667]), 'cls_max': array([2293, 2293]), 'cls_min': array([152, 152])}
# Charmeleon
# {'cls_mean': array([486.58695652, 483.10869565]), 'cls_max': array([1154, 1154]), 'cls_min': array([107, 107])}
# Clefable
# {'cls_mean': array([462.92105263, 471.97368421]), 'cls_max': array([1906, 1971]), 'cls_min': array([78, 78])}
# Clefairy
# {'cls_mean': array([410.2826087 , 413.93478261]), 'cls_max': array([1500, 1500]), 'cls_min': array([51, 51])}
# Cloyster
# {'cls_mean': array([498.08333333, 497.52083333]), 'cls_max': array([2629, 2629]), 'cls_min': array([140, 140])}
# Cubone
# {'cls_mean': array([508.35, 507.4 ]), 'cls_max': array([1535, 1535]), 'cls_min': array([116, 116])}
# Dewgong
# {'cls_mean': array([520.88372093, 524.62790698]), 'cls_max': array([1722, 1720]), 'cls_min': array([117, 117])}
# Diglett
# {'cls_mean': array([304.43589744, 306.20512821]), 'cls_max': array([827, 827]), 'cls_min': array([112, 113])}
# Ditto
# {'cls_mean': array([446.725, 452.225]), 'cls_max': array([1500, 1500]), 'cls_min': array([71, 71])}
# Dodrio
# {'cls_mean': array([389.92307692, 390.33333333]), 'cls_max': array([882, 882]), 'cls_min': array([114, 116])}
# Doduo
# {'cls_mean': array([419.17142857, 417.65714286]), 'cls_max': array([1071, 1071]), 'cls_min': array([120, 120])}
# Dragonair
# {'cls_mean': array([577.02380952, 575.19047619]), 'cls_max': array([1500, 1500]), 'cls_min': array([118, 118])}
# Dragonite
# {'cls_mean': array([517.375     , 518.85416667]), 'cls_max': array([2452, 2473]), 'cls_min': array([110, 110])}
# Dratini
# {'cls_mean': array([443.84615385, 445.30769231]), 'cls_max': array([1568, 1625]), 'cls_min': array([96, 96])}
# Drowzee
# {'cls_mean': array([339.71794872, 338.8974359 ]), 'cls_max': array([881, 887]), 'cls_min': array([112, 117])}
# Dugtrio
# {'cls_mean': array([433.17647059, 441.45098039]), 'cls_max': array([1500, 1500]), 'cls_min': array([121, 121])}
# Eevee
# {'cls_mean': array([545.62162162, 576.24324324]), 'cls_max': array([2015, 2067]), 'cls_min': array([126, 132])}
# Ekans
# {'cls_mean': array([463.61111111, 482.72222222]), 'cls_max': array([1088, 1280]), 'cls_min': array([94, 94])}
# Electabuzz
# {'cls_mean': array([480.26829268, 481.2195122 ]), 'cls_max': array([1386, 1440]), 'cls_min': array([66, 66])}
# Electrode
# {'cls_mean': array([405.76470588, 406.58823529]), 'cls_max': array([1440, 1440]), 'cls_min': array([64, 64])}
# Exeggcute
# {'cls_mean': array([440.23913043, 444.36956522]), 'cls_max': array([1414, 1414]), 'cls_min': array([109, 109])}
# Exeggutor
# {'cls_mean': array([515.8, 520.3]), 'cls_max': array([2343, 2388]), 'cls_min': array([133, 133])}
# Farfetchd
# {'cls_mean': array([422.125     , 421.27083333]), 'cls_max': array([1792, 1818]), 'cls_min': array([63, 63])}
# Fearow
# {'cls_mean': array([417.16666667, 419.39583333]), 'cls_max': array([945, 968]), 'cls_min': array([120, 121])}
# Flareon
# {'cls_mean': array([590.31111111, 589.97777778]), 'cls_max': array([1683, 1701]), 'cls_min': array([140, 144])}
# Gastly
# {'cls_mean': array([445.75      , 451.06818182]), 'cls_max': array([905, 911]), 'cls_min': array([113, 113])}
# Gengar
# {'cls_mean': array([547.32653061, 544.55102041]), 'cls_max': array([1778, 1675]), 'cls_min': array([127, 127])}
# Geodude
# {'cls_mean': array([400.77142857, 406.28571429]), 'cls_max': array([881, 921]), 'cls_min': array([111, 116])}
# Gloom
# {'cls_mean': array([469.95918367, 471.34693878]), 'cls_max': array([1500, 1500]), 'cls_min': array([74, 74])}
# Golbat
# {'cls_mean': array([420.95833333, 424.10416667]), 'cls_max': array([1056, 1063]), 'cls_min': array([119, 120])}
# Goldeen
# {'cls_mean': array([381.87234043, 383.31914894]), 'cls_max': array([1232, 1232]), 'cls_min': array([70, 70])}
# Golduck
# {'cls_mean': array([432.93478261, 433.30434783]), 'cls_max': array([1200, 1200]), 'cls_min': array([113, 110])}
# Golem
# {'cls_mean': array([408.39130435, 414.02173913]), 'cls_max': array([1167, 1225]), 'cls_min': array([105, 105])}
# Graveler
# {'cls_mean': array([429.94871795, 430.92307692]), 'cls_max': array([1326, 1326]), 'cls_min': array([120, 120])}
# Grimer
# {'cls_mean': array([382.81818182, 387.59090909]), 'cls_max': array([1000, 1000]), 'cls_min': array([57, 57])}
# Growlithe
# {'cls_mean': array([438.93181818, 438.04545455]), 'cls_max': array([1500, 1500]), 'cls_min': array([84, 84])}
# Gyarados
# {'cls_mean': array([506.73913043, 506.39130435]), 'cls_max': array([1202, 1208]), 'cls_min': array([168, 168])}
# Haunter
# {'cls_mean': array([537.91666667, 537.95833333]), 'cls_max': array([2345, 2322]), 'cls_min': array([83, 83])}
# Hitmonchan
# {'cls_mean': array([399.89361702, 398.55319149]), 'cls_max': array([1052, 1059]), 'cls_min': array([75, 75])}
# Hitmonlee
# {'cls_mean': array([469.75      , 473.39583333]), 'cls_max': array([1448, 1428]), 'cls_min': array([90, 90])}
# Horsea
# {'cls_mean': array([414.35185185, 408.09259259]), 'cls_max': array([1000,  900]), 'cls_min': array([89, 89])}
# Hypno
# {'cls_mean': array([447.        , 445.23404255]), 'cls_max': array([1080, 1103]), 'cls_min': array([125, 126])}
# Ivysaur
# {'cls_mean': array([499.925, 501.9  ]), 'cls_max': array([1118, 1114]), 'cls_min': array([84, 84])}
# Jigglypuff
# {'cls_mean': array([532.7826087 , 532.47826087]), 'cls_max': array([2199, 2199]), 'cls_min': array([130, 119])}
# Jolteon
# {'cls_mean': array([537.74509804, 537.82352941]), 'cls_max': array([1500, 1500]), 'cls_min': array([87, 87])}
# Jynx
# {'cls_mean': array([453.48979592, 456.93877551]), 'cls_max': array([1144, 1222]), 'cls_min': array([139, 139])}
# Kabuto
# {'cls_mean': array([398.36734694, 399.20408163]), 'cls_max': array([1661, 1661]), 'cls_min': array([70, 70])}
# Kabutops
# {'cls_mean': array([415.83333333, 416.95238095]), 'cls_max': array([1151, 1151]), 'cls_min': array([138, 138])}
# Kadabra
# {'cls_mean': array([414.44897959, 415.79591837]), 'cls_max': array([1080, 1086]), 'cls_min': array([88, 88])}
# Kakuna
# {'cls_mean': array([381.04255319, 380.68085106]), 'cls_max': array([1943, 1920]), 'cls_min': array([69, 69])}
# Kangaskhan
# {'cls_mean': array([409.43137255, 411.11764706]), 'cls_max': array([1543, 1543]), 'cls_min': array([113, 113])}
# Kingler
# {'cls_mean': array([431.25531915, 434.42553191]), 'cls_max': array([1073, 1076]), 'cls_min': array([108, 108])}
# Koffing
# {'cls_mean': array([473.52083333, 476.39583333]), 'cls_max': array([2869, 2857]), 'cls_min': array([100, 103])}
# Krabby
# {'cls_mean': array([388.16666667, 390.83333333]), 'cls_max': array([1758, 1758]), 'cls_min': array([69, 69])}
# Lapras
# {'cls_mean': array([556.75471698, 555.54716981]), 'cls_max': array([2381, 2381]), 'cls_min': array([122, 122])}
# Lickitung
# {'cls_mean': array([407.60416667, 408.5       ]), 'cls_max': array([903, 903]), 'cls_min': array([92, 98])}
# Machamp
# {'cls_mean': array([414.86792453, 413.73584906]), 'cls_max': array([1535, 1533]), 'cls_min': array([80, 80])}
# Machoke
# {'cls_mean': array([443.        , 440.83333333]), 'cls_max': array([1177, 1168]), 'cls_min': array([113, 113])}
# Machop
# {'cls_mean': array([415.7804878 , 414.82926829]), 'cls_max': array([1101, 1101]), 'cls_min': array([93, 93])}
# Magikarp
# {'cls_mean': array([405.34090909, 404.20454545]), 'cls_max': array([1200, 1200]), 'cls_min': array([67, 67])}
# Magmar
# {'cls_mean': array([423.97727273, 424.40909091]), 'cls_max': array([1039, 1013]), 'cls_min': array([76, 76])}
# Magnemite
# {'cls_mean': array([494.30434783, 499.        ]), 'cls_max': array([1500, 1500]), 'cls_min': array([104, 103])}
# Magneton
# {'cls_mean': array([425.80487805, 429.68292683]), 'cls_max': array([1049, 1024]), 'cls_min': array([115, 118])}
# Mankey
# {'cls_mean': array([445.05454545, 444.65454545]), 'cls_max': array([1204, 1191]), 'cls_min': array([55, 58])}
# Marowak
# {'cls_mean': array([375.43333333, 374.8       ]), 'cls_max': array([999, 986]), 'cls_min': array([96, 98])}
# Meowth
# {'cls_mean': array([510.46153846, 496.11538462]), 'cls_max': array([1254, 1254]), 'cls_min': array([165, 147])}
# Metapod
# {'cls_mean': array([407.20754717, 404.18867925]), 'cls_max': array([2048, 2048]), 'cls_min': array([63, 63])}
# Mew
# {'cls_mean': array([601.38888889, 657.18518519]), 'cls_max': array([2400, 2880]), 'cls_min': array([141, 150])}
# Mewtwo
# {'cls_mean': array([798.38461538, 810.46153846]), 'cls_max': array([1652, 1561]), 'cls_min': array([189, 188])}
# Moltres
# {'cls_mean': array([556.76744186, 556.74418605]), 'cls_max': array([1449, 1440]), 'cls_min': array([135, 135])}
# MrMime
# {'cls_mean': array([384.95555556, 387.33333333]), 'cls_max': array([1030, 1040]), 'cls_min': array([99, 99])}
# Muk
# {'cls_mean': array([449.30952381, 461.83333333]), 'cls_max': array([1200, 1200]), 'cls_min': array([109, 109])}
# Nidoking
# {'cls_mean': array([463.21153846, 466.73076923]), 'cls_max': array([1741, 1755]), 'cls_min': array([134, 134])}
# Nidoqueen
# {'cls_mean': array([488.38461538, 482.57692308]), 'cls_max': array([1074, 1074]), 'cls_min': array([126, 126])}
# Nidorina
# {'cls_mean': array([441.92682927, 442.65853659]), 'cls_max': array([1472, 1468]), 'cls_min': array([69, 69])}
# Nidorino
# {'cls_mean': array([368.29411765, 366.96078431]), 'cls_max': array([1200, 1200]), 'cls_min': array([129, 129])}
# Ninetales
# {'cls_mean': array([470.72727273, 468.65909091]), 'cls_max': array([1200, 1200]), 'cls_min': array([80, 79])}
# Oddish
# {'cls_mean': array([469.19607843, 467.2745098 ]), 'cls_max': array([1500, 1500]), 'cls_min': array([54, 54])}
# Omanyte
# {'cls_mean': array([471.57777778, 472.08888889]), 'cls_max': array([1500, 1500]), 'cls_min': array([90, 90])}
# Omastar
# {'cls_mean': array([352.6744186 , 353.58139535]), 'cls_max': array([847, 857]), 'cls_min': array([120, 120])}
# Onix
# {'cls_mean': array([515.21428571, 514.        ]), 'cls_max': array([1433, 1433]), 'cls_min': array([84, 85])}
# Paras
# {'cls_mean': array([318.93617021, 321.53191489]), 'cls_max': array([835, 837]), 'cls_min': array([71, 71])}
# Parasect
# {'cls_mean': array([422.76744186, 425.62790698]), 'cls_max': array([1200, 1200]), 'cls_min': array([47, 47])}
# Persian
# {'cls_mean': array([462.72972973, 463.7027027 ]), 'cls_max': array([1200, 1200]), 'cls_min': array([131, 131])}
# Pidgeot
# {'cls_mean': array([442.51162791, 441.48837209]), 'cls_max': array([1080, 1094]), 'cls_min': array([120, 120])}
# Pidgeotto
# {'cls_mean': array([372.175, 373.   ]), 'cls_max': array([877, 900]), 'cls_min': array([97, 98])}
# Pidgey
# {'cls_mean': array([356.72916667, 353.66666667]), 'cls_max': array([900, 906]), 'cls_min': array([42, 43])}
# Pikachu
# {'cls_mean': array([924.82258065, 912.67741935]), 'cls_max': array([2348, 2348]), 'cls_min': array([108, 109])}
# Pinsir
# {'cls_mean': array([407.75609756, 412.29268293]), 'cls_max': array([1429, 1466]), 'cls_min': array([111, 111])}
# Poliwag
# {'cls_mean': array([393.54901961, 394.11764706]), 'cls_max': array([1000, 1000]), 'cls_min': array([109, 109])}
# Poliwhirl
# {'cls_mean': array([511.42, 511.8 ]), 'cls_max': array([3408, 3447]), 'cls_min': array([62, 62])}
# Poliwrath
# {'cls_mean': array([450.67741935, 452.80645161]), 'cls_max': array([879, 889]), 'cls_min': array([166, 166])}
# Ponyta
# {'cls_mean': array([515.35555556, 514.8       ]), 'cls_max': array([3526, 3526]), 'cls_min': array([83, 80])}
# Porygon
# {'cls_mean': array([404.65217391, 405.43478261]), 'cls_max': array([2992, 3045]), 'cls_min': array([54, 54])}
# Primeape
# {'cls_mean': array([445.56862745, 442.98039216]), 'cls_max': array([1216, 1168]), 'cls_min': array([130, 131])}
# Psyduck
# {'cls_mean': array([506.075, 501.2  ]), 'cls_max': array([1500, 1500]), 'cls_min': array([131, 131])}
# Raichu
# {'cls_mean': array([500.37254902, 503.29411765]), 'cls_max': array([1500, 1500]), 'cls_min': array([138, 134])}
# Rapidash
# {'cls_mean': array([463.83333333, 457.125     ]), 'cls_max': array([1280, 1280]), 'cls_min': array([102, 102])}
# Raticate
# {'cls_mean': array([385.        , 396.92682927]), 'cls_max': array([954, 914]), 'cls_min': array([72, 72])}
# Rattata
# {'cls_mean': array([474.44186047, 483.86046512]), 'cls_max': array([2384, 2457]), 'cls_min': array([100, 100])}
# Rhydon
# {'cls_mean': array([529.12, 542.16]), 'cls_max': array([2450, 2581]), 'cls_min': array([93, 94])}
# Rhyhorn
# {'cls_mean': array([452.75609756, 454.31707317]), 'cls_max': array([3138, 3182]), 'cls_min': array([122, 123])}
# Sandshrew
# {'cls_mean': array([349.10869565, 342.82608696]), 'cls_max': array([900, 836]), 'cls_min': array([81, 81])}
# Sandslash
# {'cls_mean': array([409.4       , 410.44444444]), 'cls_max': array([900, 900]), 'cls_min': array([120, 120])}
# Scyther
# {'cls_mean': array([559.61403509, 560.28070175]), 'cls_max': array([1900, 1900]), 'cls_min': array([87, 87])}
# Seadra
# {'cls_mean': array([461.39583333, 462.33333333]), 'cls_max': array([1200, 1200]), 'cls_min': array([120, 120])}
# Seaking
# {'cls_mean': array([415.5       , 417.65217391]), 'cls_max': array([1163, 1163]), 'cls_min': array([94, 94])}
# Seel
# {'cls_mean': array([380.39583333, 391.25      ]), 'cls_max': array([1160, 1177]), 'cls_min': array([ 97, 105])}
# Shellder
# {'cls_mean': array([346.73913043, 356.93478261]), 'cls_max': array([1071, 1090]), 'cls_min': array([107, 108])}
# Slowbro
# {'cls_mean': array([470.80434783, 477.36956522]), 'cls_max': array([1200, 1200]), 'cls_min': array([120, 120])}
# Slowpoke
# {'cls_mean': array([399.02439024, 408.3902439 ]), 'cls_max': array([1536, 1575]), 'cls_min': array([44, 45])}
# Snorlax
# {'cls_mean': array([597.18644068, 617.27118644]), 'cls_max': array([2450, 2581]), 'cls_min': array([150, 141])}
# Spearow
# {'cls_mean': array([431.61818182, 429.4       ]), 'cls_max': array([2589, 2460]), 'cls_min': array([64, 74])}
# Squirtle
# {'cls_mean': array([800.36538462, 799.63461538]), 'cls_max': array([1515, 1515]), 'cls_min': array([137, 140])}
# Starmie
# {'cls_mean': array([469.71428571, 489.69387755]), 'cls_max': array([1920, 1920]), 'cls_min': array([62, 63])}
# Staryu
# {'cls_mean': array([367.        , 368.80851064]), 'cls_max': array([1080, 1124]), 'cls_min': array([47, 48])}
# Tangela
# {'cls_mean': array([373.90566038, 379.96226415]), 'cls_max': array([1200, 1200]), 'cls_min': array([68, 66])}
# Tauros
# {'cls_mean': array([429.64814815, 432.66666667]), 'cls_max': array([881, 912]), 'cls_min': array([76, 73])}
# Tentacool
# {'cls_mean': array([361.31111111, 357.53333333]), 'cls_max': array([1200, 1164]), 'cls_min': array([75, 77])}
# Tentacruel
# {'cls_mean': array([388.12765957, 391.53191489]), 'cls_max': array([1200, 1200]), 'cls_min': array([113, 120])}
# Vaporeon
# {'cls_mean': array([544.30508475, 532.13559322]), 'cls_max': array([1500, 1500]), 'cls_min': array([123, 141])}
# Venomoth
# {'cls_mean': array([454.44230769, 473.65384615]), 'cls_max': array([1630, 1729]), 'cls_min': array([120, 120])}
# Venonat
# {'cls_mean': array([435.68085106, 422.78723404]), 'cls_max': array([1155, 1061]), 'cls_min': array([108, 107])}
# Venusaur
# {'cls_mean': array([583.37878788, 749.43939394]), 'cls_max': array([1500, 2158]), 'cls_min': array([165, 220])}
# Victreebel
# {'cls_mean': array([451.08163265, 463.91836735]), 'cls_max': array([1172, 1355]), 'cls_min': array([92, 92])}
# Vileplume
# {'cls_mean': array([396.60714286, 415.69642857]), 'cls_max': array([1239, 1391]), 'cls_min': array([120, 115])}
# Voltorb
# {'cls_mean': array([394.50909091, 393.83636364]), 'cls_max': array([1688, 1636]), 'cls_min': array([67, 60])}
# Vulpix
# {'cls_mean': array([539.88, 539.76]), 'cls_max': array([1644, 1666]), 'cls_min': array([115, 108])}
# Wartortle
# {'cls_mean': array([473.4375    , 462.85416667]), 'cls_max': array([1669, 1669]), 'cls_min': array([113, 114])}
# Weedle
# {'cls_mean': array([410.95918367, 395.65306122]), 'cls_max': array([1648, 1514]), 'cls_min': array([68, 70])}
# Weepinbell
# {'cls_mean': array([398.58139535, 409.27906977]), 'cls_max': array([975, 990]), 'cls_min': array([76, 76])}
# Weezing
# {'cls_mean': array([394.92, 416.16]), 'cls_max': array([1064, 1413]), 'cls_min': array([119, 121])}
# Wigglytuff
# {'cls_mean': array([386.84210526, 379.12280702]), 'cls_max': array([1387, 1387]), 'cls_min': array([68, 64])}
# Zapdos
# {'cls_mean': array([452.47058824, 460.2745098 ]), 'cls_max': array([1352, 1370]), 'cls_min': array([84, 84])}
# Zubat
# {'cls_mean': array([449.525, 453.35 ]), 'cls_max': array([1920, 1920]), 'cls_min': array([95, 95])}

# %%
# средний максимум по высоте
arr = np.array(stastics_arr)
print(f"Среднее по высоте: {arr[:, 0, 0].mean()}")
#stastics_arr[:, 0, 0].max()
# Out:
# Среднее по высоте: 464.04255567163557

# %%
# средний максимум по ширине
print(f"Среднее по ширине: {arr[:, 0, 1].mean()}")
#stastics_arr[:, 0, 1].max()
# Out:
# Среднее по ширине: 467.8378539075421

# %%
# Выберем один размер для всех изображений
#mean_size = [465, 465]
size = [200, 200]
size
# Out:
# [200, 200]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Проверим, сохранятся ли пропорции изображения при изменении размера

# %%
for cls in os.listdir(DATA_PATH):
    cls_path = os.path.join(DATA_PATH, cls)
    #print(os.listdir(cls_path))
    for img_name in os.listdir(cls_path):
        img_path = os.path.join(cls_path, img_name)
        #print(img_path)
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.figure(figsize=(2, 2))
        plt.imshow(img)
        plt.title("Оригинальное изображение")
        plt.show()

        stretch_near = cv2.resize(img, size, interpolation = cv2.INTER_LINEAR)
        
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.figure(figsize=(2, 2))
        plt.imshow(stretch_near)
        plt.title("Измененное изображение")
        plt.show()

        # cv2.imshow("Shrinked", stretch_near)
        # cv2.waitKey(0)
        # cv2.destroyAllWindows()
        break
    break

# %% [markdown]
# Сохраним измененный датасет

# %%
AUGMENTED_DATA_PATH = r'D:\ProgrammingPython\neural_networks\PokemonData_200'
if not os.path.exists(AUGMENTED_DATA_PATH):
    os.makedirs(AUGMENTED_DATA_PATH)

# %%
# Изменяем все изображения в датасете, чтобы размер был (200, 200)
for cls in os.listdir(DATA_PATH):
    cls_path = os.path.join(DATA_PATH, cls)
    cls_aug_path = os.path.join(AUGMENTED_DATA_PATH, cls)
    if not os.path.exists(cls_aug_path):
        os.makedirs(cls_aug_path)
    os.chdir(cls_aug_path) 
    #print(os.listdir(cls_path))
    for img_name in os.listdir(cls_path):
        img_path = os.path.join(cls_path, img_name)
        #print(img_name)
        aug_img_path = os.path.join(cls_aug_path, cls)
        #print(img_path)
        img = cv2.imread(img_path)

        stretch_near = cv2.resize(img, size, interpolation = cv2.INTER_LINEAR)
        
        #print(img_name)
        cv2.imwrite(img_name, stretch_near)

# %%
DATA_PATH = r'D:\ProgrammingPython\neural_networks\PokemonData_200'
classes = {n: cls for n,cls in enumerate(os.listdir(DATA_PATH))}
classes_invert = {value:key for key, value in classes.items() }

class PokemonDataset(Dataset):
    
    def __init__(self, rootdir, transform) -> None:
        super().__init__()
        self.class_names = os.listdir(rootdir)
        self.class_idx = [i for i in range(len(self.class_names))]
        self.transform = transform
        self.images_pathes = []
        self.images_clas_names = []

        for cls_name in self.class_names:
            sub_root = os.path.join(rootdir, cls_name)
            self.images_pathes.extend(glob.glob(os.path.join(sub_root, '*.jpg')))
            self.images_clas_names.append(cls_name)

        random.shuffle(self.images_pathes)
            
    def __len__(self):
        return len(self.images_pathes)
    
    def __getitem__(self, index) -> tuple:

        img_path = self.images_pathes[index]
        image = cv2.imread(img_path)
        img_folder_pth = os.path.split(img_path)[0]
        cls_name = os.path.split(img_folder_pth)[-1]
        label = self.class_names.index(cls_name)
        
        if self.transform:
            image = self.transform(image)

        return (image, label)

# %%
transform = transforms.Compose(
    [
        transforms.ToTensor(), 
        transforms.Normalize(mean = 0.5, std = 0.5)
    ]
)

# %%
from torch.utils.data import DataLoader, random_split
from sklearn.model_selection import train_test_split

# %% [markdown]
# Оригинальный датасет не разделен на тренировочную и тестовую выборки, поэтому разделим датасет в соотношении 80 на 20

# %%
TEST_SIZE = 0.2
BATCH_SIZE = 64
SEED = 42

# %%
dataset = PokemonDataset(DATA_PATH, transform)

# %%
generator = torch.Generator().manual_seed(SEED)

train_dataset, test_dataset = random_split(dataset, [1-TEST_SIZE, TEST_SIZE], generator=generator)

# %%
train_loader = DataLoader(dataset, batch_size=BATCH_SIZE)

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

# %%
for x,y in train_loader:
    print(x.shape)
    print(y)
    break
# Out:
# torch.Size([64, 3, 200, 200])
# tensor([ 70,  90,   9,  11,  56, 101,  23,   8,  69,  41,  92, 141,  37,  69,
#         104,  17,  55,  27,  76,  49,  65,  52,  39, 126,  29,  44,  80, 147,
#          83, 132, 102, 105,  69,  55,  23, 145,  39, 149,  98,  99,  36,  45,
#          73, 136,  45, 141,  51,  37,  71,  10, 132,  92, 135,  86,  93,  34,
#          73,  17,  32,  26, 147,  66, 123, 131])

# %% [markdown]
# ## Модель

# %%
# выход с последнего слоя
print(f"Кол-во классов: {len(classes.values())}")
# Out:
# Кол-во классов: 150

# %%
print(229//2)
# Out:
# 114

# %% [markdown]
# Имеем входной тензор 200 на 200.
#
# Вычисляем кол-во нейронов на полносвязном слое.
#
# (200 - 3 + 1) // 2 = 99
#
# (99 - 3 + 1) // 2 = 48
#
# (48 - 3 + 1) // 2 = 23
#
# 32 * 23 * 23 = 16928

# %%
class PokemonClassificator(nn.Module):
    def __init__(self):
        super(PokemonClassificator, self).__init__()
        self.conv_1 = nn.Conv2d(3, 8, (3,3), 1)
        self.avPoll_1 = nn.AvgPool2d((2,2), 2)
        self.conv_2 = nn.Conv2d(8, 16, (3,3), 1)
        self.avPoll_2 = nn.AvgPool2d((2,2), 2)
        self.conv_3 = nn.Conv2d(16, 32, (3,3), 1)
        self.avPoll_3 = nn.AvgPool2d((2,2), 2)
        self.linear_1 = nn.Linear(16928, 1024)
        self.linear_2 = nn.Linear(1024, 150)


    def forward(self, x):
        x = self.conv_1(x)
        x = F.tanh(x)
        x = self.avPoll_1(x)
        x = F.tanh(x)

        x = self.conv_2(x)
        x = F.tanh(x)
        x = self.avPoll_2(x)
        x = F.tanh(x)

        x = self.conv_3(x)
        x = F.tanh(x)
        x = self.avPoll_3(x)
        x = F.tanh(x)

        x = torch.flatten(x, start_dim=1)

        x = self.linear_1(x)
        x = F.tanh(x)
        x = self.linear_2(x)
        
        return x

# %%
model = PokemonClassificator()
model.to(device)
loss_function = torch.nn.CrossEntropyLoss()

optimizator = torch.optim.Adam(model.parameters(), lr=0.001,)

# %%
def val(model, test_loader):
    model.eval()
    tp = 0
    total = 0

    for x,y in test_loader:
        y = y.to(device)
        pred = torch.argmax(model(x.to(device)), dim=1)
        tp += int((pred == y).sum().to('cpu'))
        total +=len(pred)
    
    return tp/total

def train(dataloader, model, loss_fn, op_fn, epoch):
    acc = 0
    for ep in range(epoch):
        for step, (x, y) in enumerate(dataloader):


            y_pred = model(x.to(device))
            loss = loss_fn(y_pred.to(device), y.to(device))

            op_fn.zero_grad()
            loss.backward()
            op_fn.step()

            if step%100 == 0:
                loss, current = loss.item(), (ep+1)*(step+1)*BATCH_SIZE
                print(f"loss = {loss}, samples = {current}")

        acc = val(model, test_loader)
        print('precision =', acc)

        #torch.save(model, f'pokemon_classifier_{epoch}_{acc}.pt')

    return acc

# %%
accuracy = train(train_loader, model, loss_function, optimizator, 5)
# Out:
# loss = 5.009308338165283, samples = 64
# loss = 2.889683485031128, samples = 6464
# precision = 0.4462809917355372
# loss = 2.250178098678589, samples = 128
# loss = 2.2074460983276367, samples = 12928
# precision = 0.613824192336589
# loss = 1.6509324312210083, samples = 192
# loss = 1.8139111995697021, samples = 19392
# precision = 0.6972201352366642
# loss = 1.22444486618042, samples = 256
# loss = 1.170702576637268, samples = 25856
# precision = 0.7648384673178061
# loss = 1.1151248216629028, samples = 320
# loss = 0.6962911486625671, samples = 32320
# precision = 0.8865514650638617

# %% [markdown]
# Сохраним модель, указав датасет, кол-во эпох и точность

# %%
accuracy = (accuracy*100)
output_str = f"pokemon_200_classifier_5_{accuracy:.2f}"
output_str = output_str.replace(".", "_")
output_str = output_str + '.pt'
print(output_str)
# Out:
# pokemon_200_classifier_5_88_66.pt

# %%
torch.save(model, output_str)

# %% [markdown]
# ## Оценка модели

# %%
model.to('cpu')
model(x).size()
# Out:
# torch.Size([64, 150])

# %%
model.eval()
# Out:
# PokemonClassificator(
#   (conv_1): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1))
#   (avPoll_1): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#   (conv_2): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#   (avPoll_2): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#   (conv_3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (avPoll_3): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#   (linear_1): Linear(in_features=16928, out_features=1024, bias=True)
#   (linear_2): Linear(in_features=1024, out_features=150, bias=True)
# )

# %%
predicts = []
labels = []

for x,y in test_loader:
    y = y.to('cpu').numpy()
    pred = torch.argmax(model(x.to('cpu')), dim=1).to('cpu').numpy()
    predicts.append(pred)
    labels.append(y)

print(len(predicts))
# Out:
# 21

# %% [markdown]
# Посмотрим ответы модели
#
# С помощью num_in_batch выбираем картинку в первом batch

# %%
num_in_batch = 1
for x,y in test_loader:
    # Преобразование значений изображения из диапазона [-1, 1] в диапазон [0, 1]
    img = (x[num_in_batch].numpy().transpose(1, 2, 0) + 1) / 2
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(2, 2))
    plt.axis('off')
    # Преобразование значений изображения из диапазона [0, 1] в диапазон [0, 255] (Перемешались цвет. каналы)
    plt.imshow((img*255).astype('int32'))
    plt.title(classes[int(y[num_in_batch])])
    plt.show()
    print(f'Истинная метка: {y[num_in_batch].numpy()} - {classes[int(y[num_in_batch])]}')
    print(f'Предсказ метка: {predicts[0][num_in_batch]} - {classes[int(predicts[0][num_in_batch])]}')
    break
# Out:
# Истинная метка: 82 - Mew
# Предсказ метка: 82 - Mew

# %%
predicts = np.concatenate(predicts)
labels = np.concatenate(labels)

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(labels, predicts, labels=tuple(classes.keys()))

# %%
cm.shape
# Out:
# (150, 150)

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(60, 40))
    plt.rcParams.update({'font.size': 56})
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
plot_confusion_matrix(cm, tuple(classes.values()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 plot_confusion_matrix(cm, tuple(classes.values()))
#
# NameError: name 'cm' is not defined

# %%
plot_confusion_matrix(cm[:5,:5], tuple(classes.values())[:5])
